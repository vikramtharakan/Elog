# %% [markdown]
# # Elog Tagging
#
# The goal is to try and tag elog entries with the correct tag. In order to do this we need to:
# * Scrape the data from the entries off the elog
# * Also get the corresponding tag for entries
# * Run through NLP algorithm to try and train the entries (NOTE: Can't really do this rn because all of our tagging is kinda horseshit so we'd be training it on poop data

# %%
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from sqlalchemy import create_engine

# %%
def get_data(s,e):
    '''
    --- Imports data from Elog and stores it in a workable format ---
    INPUT
        s: start time as unix timestamp
        e: end time as unix time stamp
    RETURN
        df: dataframe of uncleaned data between selected time range
    '''
    
    # api-endpoint 
    URL = "https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_elog_display_json.php"

    PARAMS = {'logbook': 'MCC', 'start': s, 'end': e} 

    # sending get request and saving the response as response object 
    r = requests.get(url = URL, params = PARAMS) 

    # extracting data in json format 
    data = r.json()

    # Turning list of json objects into dataframe
    df = pd.DataFrame.from_records(data)

    return df

# %%
# Just checking that things work as expected
s = datetime(2008, 1, 11, 0, 0).timestamp()
e = datetime(2009, 1, 11, 0, 0).timestamp()
df = get_data(s,e)
print(df.shape)
df.head()
# Out:
# (24284, 14)
#    elogid                                             title  \
# 0  270417  MCC Shift Change: Owl Shift, Sunday, 11-Jan-2009
# 1  270419                               SWING SHIFT SUMMARY
# 2  270415                      * RE: Frisch 6x6 misbehaving
# 3  270412               Instructions for resetting BSOBTH02
# 4  270413                            Frisch 6x6 misbehaving
#
#                                                 text  \
# 0  .250 nC 13.6 GeV 10 Hz e- to main dump. Undula...
# 1  <table CellPadding=5 BORDER=1>\n\t\t <TR><TD><...
# 2  Disabled BSY/LTU energy part of Frisch feedbac...
# 3  Go to the large blue box on the <u>North</u> h...
# 4  LTU energy BPM DL1 oscillating about 2mm.  Pag...
#
#                              logbook  \
# 0  {'logbookid': 122, 'name': 'MCC'}
# 1  {'logbookid': 122, 'name': 'MCC'}
# 2  {'logbookid': 122, 'name': 'MCC'}
# 3  {'logbookid': 122, 'name': 'MCC'}
# 4  {'logbookid': 122, 'name': 'MCC'}
#
#                                               author   eventTime  \
# 0  {'authorid': 1053, 'username': 'spw', 'firstna...  1231660800
# 1  {'authorid': 1161, 'username': 'jwarren', 'fir...  1231660799
# 2  {'authorid': 1161, 'username': 'jwarren', 'fir...  1231660530
# 3  {'authorid': 1160, 'username': 'jab', 'firstna...  1231660060
# 4  {'authorid': 1161, 'username': 'jwarren', 'fir...  1231659900
#
#                          shift  children    parent attachments  superseded_by  \
# 0    Owl Shift, Sun, 11-Jan-09       NaN       NaN         NaN            NaN
# 1  Swing Shift, Sat, 10-Jan-09       NaN       NaN         NaN            NaN
# 2  Swing Shift, Sat, 10-Jan-09  [270428]  270413.0         NaN            NaN
# 3  Swing Shift, Sat, 10-Jan-09       NaN       NaN         NaN            NaN
# 4  Swing Shift, Sat, 10-Jan-09  [270415]       NaN         NaN            NaN
#
#    supersedes highPriority  tag
# 0         NaN          NaN  NaN
# 1         NaN          NaN  NaN
# 2         NaN          NaN  NaN
# 3         NaN          NaN  NaN
# 4         NaN          NaN  NaN

# %% [markdown]
# ### Now we have a method to store the data in the data frame but there still is a lot of useless data here. Let's get rid of useless columns
#
# * logbook (all mcc)
# * author, eventTime, shift, parent, children, attachments, supersedes (irrelevant)
#
# This leaves the following columns left: `title`, `text`, `elog_id`, `tag`, and `superceded_by`
# * `superceded_by` is useful because any column where this is not Nan, we can drop this. The reasoning behind this is that there basically are duplicate entries (when an entry is superceded) and we only want to keep one copy (the correct one). So we can drop the original entries, i.e. the entries where `superceded_by` is not Nan, and then delete this column
#
# Finally we'd be left with: `title`, `text`, `elog_id`, `tag` <br>
# <b> Questions </b>
# * NLP algorithm should really only be working on the `titl`e of the entries right? Like that's great if there are more key words in the body, but the title should be enough to tag the location (in my head). If this is true than there's no need for `text`
# * Do I really need `elog_id` for anything...? If I keep title and text I definitely need to, if not then I see no need

# %%
def clean_data(df):
    '''
    --- Cleans data frame ---
    INPUT
        df: dataframe (not cleaned)
    RETURN
        df: dataframe (cleaned)
    '''
    # Dropping rows without any tags (these rows are useless for us)
    df = df[df.tag.notnull() == True]
    
    # Dropping useless columns
    important_cols = {'title', 'text', 'elogid', 'tag', 'superseded_by'}
    list1 = df.columns.tolist()
    list1 = [ele for ele in list1 if ele not in important_cols]
    for column in df.columns.tolist():
        if column in list1:
            df = df.drop(column,axis = 1)

    # Dropping all columns where superceded_by is not null to essentially drop duplicates. Then drop superceded_by column
    df = df[df['superseded_by'].isnull() == True]
    df = df.drop(['superseded_by'],axis = 1)
    
    # Reset the index
    df = df.reset_index(drop=True)
    
    return df

# %%
# Just checking that things work as expected
df = clean_data(df)
print(df.shape)
df.head()
# Out:
# (49, 4)
#    elogid                                              title  \
# 0  265530                 Restart LCLS Magnet ChannelWatcher
# 1  259842                           BYKIK pulse width change
# 2  252459            * Re: SW: Reboot BC1 Bunch Length IOCs-
# 3  252453                  SW: Reboot BC1 Bunch Length IOCs-
# 4  252399  Fallout from 120Hz Testing: BCS: Gun SBI (20-5...
#
#                                                 text   tag
# 0  I've restarted the lcls magnet channel watcher...  LCLS
# 1  Tony Beukers and I chagned the BYKIK pulse wid...  LCLS
# 2  Greg Dallt from the Klystron Group is working ...  LCLS
# 3  Rebooted Bunch Length Monitor EPICS IOC in li2...  LCLS
# 4  Hello,\n\nAfter the 120Hz testing, after the c...  LCLS

# %%
# Checking to see the number of tags present
df.tag.value_counts()
# Out:
# LCLS    49
# Name: tag, dtype: int64

# %% [markdown]
# <b> Now lets save the data in a way that we can easily access </b>

# %%
# Function to save the data into sql database
def save_data(df, database_filename):
    engine = create_engine('sqlite:///'+database_filename+'.db')
    df.to_sql(database_filename, engine, index=False)
    
    '''
    if only_tags == True:
        df.to_sql(database_filename, conn, if_exists='replace', index = False)
    
    
    if only_tags == False:
        df_big = np.array_split(df, n)
        chunk_list = list(range(0,n))
        for i in chunk_list:
            df_big[i].to_sql(database_filename+str(i), conn, if_exists='replace', index = False)
    '''

# %% [markdown]
# ### Important changes that still need to be made:
# * What time frame is a good time frame to capture all needed data???
# > Looks like you want to capture data up till 2011. Perhaps the most efficient way to do this would be either by month or year and then process this data individually and recreate a giant dataframe. You would likely have to add more methods to your main() class and add a function that incorporates this

# %%
def main():
    '''
    Will go through all the necessary steps to extract the data from the elog, clean it, and save the data
    in an SQL database
    '''
    s = datetime(2009, 1, 11, 0, 0).timestamp()
    e = datetime(2010, 1, 11, 0, 0).timestamp()
    df = get_data(s,e)
    df = clean_data(df)
    save_data(df,'elog_data')

# %%
# Running this will save the data that we want to collect
main()

# %% [markdown]
# ### Due to what was found in the cells below, we realize that there are duplicates
# We'll need to rewrite out `clean_data` function to incorporate a few things:
# * This function should drop duplicates
#
# Also will need to write another function that does the following (call it `join_data_2011`):
# * Uses `get_data` and collects data in one month intervals
# * Cleans these individual months using the new `clean_data` function
# * Joins the months together
# * Drops duplicates if there is any overlap

# %%
# Creating dummy dataframe
s = datetime(2011, 4, 1, 0, 0).timestamp()
e = datetime(2011, 8, 1, 0, 0).timestamp()
df1 = get_data(s,e)
print('Number of entries in this dataframe: ' + str(df1.shape[0]))

# Printing out duplicates, just so that we have the visual proof
print('The duplicates for this one month period of time are shown below. Must be something wrong with the query')
bad_ids = df1[df1.elogid.duplicated() == True].elogid.tolist()
print('Number of entries in this duplicates dataframe: ' + str(df1[df1['elogid'].isin(bad_ids) == True].shape[0]))
df1[df1['elogid'].isin(bad_ids) == True]
# Out:
# Number of entries in this dataframe: 8663
# The duplicates for this one month period of time are shown below. Must be something wrong with the query
# Number of entries in this duplicates dataframe: 128
#       elogid                                   title  \
# 105   515398                          FACET Summary:
# 106   515398                          FACET Summary:
# 587   514588                              MD summary
# 588   514588                              MD summary
# 1193  511531                           FACET summary
# ...      ...                                     ...
# 8142  484955          * Re: Vacuum degraded  in LI25
# 8143  484956          * Re: Vacuum degraded  in LI25
# 8144  484956          * Re: Vacuum degraded  in LI25
# 8265  483960  * Re: switched to 60Hz BGRP for K Kim.
# 8266  483960  * Re: switched to 60Hz BGRP for K Kim.
#
#                                                    text  \
# 105       * Recover beam to FACET dump & scav ext. l...
# 106       * Recover beam to FACET dump & scav ext. l...
# 587   1) Cathode cleaning\n2) CQ/SQ01 scans on IN20 ...
# 588   1) Cathode cleaning\n2) CQ/SQ01 scans on IN20 ...
# 1193  <b>Program</b>\n1) OTR size v. sext\n2) etax/e...
# ...                                                 ...
# 8142
# 8143
# 8144
# 8265            Switched back to 120 Hz for the moment.
# 8266            Switched back to 120 Hz for the moment.
#
#                                 logbook  \
# 105   {'logbookid': 122, 'name': 'MCC'}
# 106   {'logbookid': 122, 'name': 'MCC'}
# 587   {'logbookid': 122, 'name': 'MCC'}
# 588   {'logbookid': 122, 'name': 'MCC'}
# 1193  {'logbookid': 122, 'name': 'MCC'}
# ...                                 ...
# 8142  {'logbookid': 122, 'name': 'MCC'}
# 8143  {'logbookid': 122, 'name': 'MCC'}
# 8144  {'logbookid': 122, 'name': 'MCC'}
# 8265  {'logbookid': 122, 'name': 'MCC'}
# 8266  {'logbookid': 122, 'name': 'MCC'}
#
#                                                  author   eventTime  \
# 105   {'authorid': 1301, 'username': 'mgibbs', 'firs...  1312009104
# 106   {'authorid': 1062, 'username': 'cfh', 'firstna...  1312009104
# 587   {'authorid': 1242, 'username': 'cmelton', 'fir...  1311717711
# 588   {'authorid': 1374, 'username': 'aegger', 'firs...  1311717711
# 1193  {'authorid': 1242, 'username': 'cmelton', 'fir...  1311087473
# ...                                                 ...         ...
# 8142  {'authorid': 1051, 'username': 'hvs', 'firstna...  1305161247
# 8143  {'authorid': 1003, 'username': 'stanek', 'firs...  1305161247
# 8144  {'authorid': 1051, 'username': 'hvs', 'firstna...  1305161247
# 8265  {'authorid': 1265, 'username': 'alsberg', 'fir...  1304537663
# 8266  {'authorid': 1056, 'username': 'cjb', 'firstna...  1304537663
#
#                             shift    tag    parent children  superseded_by  \
# 105   Swing Shift, Fri, 29-Jul-11  FACET       NaN      NaN            NaN
# 106   Swing Shift, Fri, 29-Jul-11  FACET       NaN      NaN            NaN
# 587     Day Shift, Tue, 26-Jul-11   LCLS       NaN      NaN       514591.0
# 588     Day Shift, Tue, 26-Jul-11   LCLS       NaN      NaN       514591.0
# 1193    Owl Shift, Tue, 19-Jul-11  FACET       NaN      NaN            NaN
# ...                           ...    ...       ...      ...            ...
# 8142  Swing Shift, Wed, 11-May-11    NaN  484935.0      NaN       484956.0
# 8143  Swing Shift, Wed, 11-May-11    NaN  484935.0      NaN            NaN
# 8144  Swing Shift, Wed, 11-May-11    NaN  484935.0      NaN            NaN
# 8265    Day Shift, Wed, 04-May-11    NaN  483959.0      NaN            NaN
# 8266    Day Shift, Wed, 04-May-11    NaN  483959.0      NaN            NaN
#
#       supersedes                                        attachments  \
# 105     515397.0                                                NaN
# 106     515397.0                                                NaN
# 587     514587.0  [{'attachmentid': 250859, 'url': 'https://mcce...
# 588     514587.0  [{'attachmentid': 250859, 'url': 'https://mcce...
# 1193         NaN                                                NaN
# ...          ...                                                ...
# 8142         NaN  [{'attachmentid': 234939, 'url': 'https://mcce...
# 8143    484955.0  [{'attachmentid': 234940, 'url': 'https://mcce...
# 8144    484955.0  [{'attachmentid': 234940, 'url': 'https://mcce...
# 8265         NaN                                                NaN
# 8266         NaN                                                NaN
#
#      highPriority
# 105           NaN
# 106           NaN
# 587           NaN
# 588           NaN
# 1193          NaN
# ...           ...
# 8142          NaN
# 8143          NaN
# 8144          NaN
# 8265          NaN
# 8266          NaN
#
# [128 rows x 14 columns]

# %%
print('Number of total tags:\n' + str(df1['tag'].value_counts())+ '\n')
print('Number of tags on duplicates:\n' + str(df1[df1['elogid'].isin(bad_ids) == True].tag.value_counts()))
# Out:
# Number of total tags:
# LCLS     698
# FACET    331
# Name: tag, dtype: int64
#
# Number of tags on duplicates:
# FACET    12
# LCLS      2
# Name: tag, dtype: int64

# %%
# Apparently there are some entries with more than 2 duplicates
df1[df1['elogid'].isin(bad_ids) == True].elogid.value_counts()[:5]
# Out:
# 488157    6
# 496626    6
# 488162    6
# 488164    4
# 488518    2
# Name: elogid, dtype: int64

# %%
# Dropping the duplicates
df11 = df1.drop_duplicates(subset ="elogid", keep = 'first')
print('After dropping the duplicates, the total length is now: ' +str(df11.shape[0]))
df11[df11['elogid'].isin(bad_ids) == True].shape[0]
# Out:
# After dropping the duplicates, the total length is now: 8592
# 57

# %%
# Will use later to make sure functions are working correctly
df11 = clean_data(df11)
print(df11.shape[0])
df11['tag'].value_counts()
# Out:
# 802
# LCLS     554
# FACET    248
# Name: tag, dtype: int64

# %% [markdown]
# ### Writing second versions of functions down below to make things clearer

# %%
def clean_data(df, only_tags = True):
    '''
    --- Cleans data frame ---
    INPUT
        df: dataframe (not cleaned)
    RETURN
        df: dataframe (cleaned)
    '''
    # Checks to make sure there are even entries with a tag in the specified month
    if only_tags == True:
        if 'tag' not in df.columns:
            return 0

        # Dropping rows without any tags (these rows are useless for us)
        df = df[df.tag.notnull() == True]
    
    # Dropping useless columns
    important_cols = {'title', 'text', 'elogid', 'tag', 'superseded_by'}
    list1 = df.columns.tolist()
    list1 = [ele for ele in list1 if ele not in important_cols]
    for column in df.columns.tolist():
        if column in list1:
            df = df.drop(column,axis = 1)

    # Dropping all columns where superceded_by is not null to essentially drop duplicates. Then drop superceded_by column
    df = df[df['superseded_by'].isnull() == True]
    df = df.drop(['superseded_by'],axis = 1)
    df = df.drop_duplicates(subset ="elogid", keep = 'first')
    
    # Reset the index
    df = df.reset_index(drop=True)
    
    return df

# %%
# Checking to see if new clean function works
s = datetime(2012, 1, 1, 0, 0).timestamp()
e = datetime(2012, 2, 1, 0, 0).timestamp()
df2 = get_data(s,e)
df2 = clean_data(df2, only_tags = False)

# %%
print(df2.shape[0])
df2.tag.value_counts()
# Out:
# 1768
# LCLS     766
# FACET     31
# Name: tag, dtype: int64

# %%
df2.fillna(value={'tag': '0'})
df2.head()
# Out:
#    elogid   tag                                               text  \
# 0  567842   NaN              Continue HXRSS studies\nTune-up 40 pC
# 1  567843   NaN  <table CellPadding="5" BORDER=1>\n<tr>\n<th>Co...
# 2  567834  LCLS  But tuning was at a -40 MeV vernier. Franz-Jos...
# 3  567822  LCLS  And seeing results in the seeding (baseline co...
# 4  567816  LCLS  No problems indicated during the switch or at ...
#
#                                                title
# 0  MCC Shift Change: Owl Shift, Wednesday, 01-Feb...
# 1                                SWING SHIFT SUMMARY
# 2                               SASE tuning - 600uJ!
# 3                      Starting Decker vernier scans
# 4  Using Matlab UND launch fbk now. Switched with...

# %% [markdown]
# ### Now create a `join_data_2011` function that will use `get_data` and `clean_data` to aquire the data up until the end of 2011

# %%
def join_data_2011():
    '''
    --- Builds one giant dataframe by concating data frames together one month at a time ---
    RETURN
        df: Cleaned dataframe of tagged entries from April 2007 - December 2011.    
    '''
    year_list = [2007,2008,2009,2010,2011]
    month_list = list(range(1,13))
    df = pd.DataFrame(columns=['elogid', 'title', 'text', 'tag'])
    for year in year_list:
        for month in month_list:
            if (year == 2007 and month < 4):
                continue
            elif (month == 12):
                s = datetime(year, month, 1, 0, 0).timestamp()
                e = datetime(year+1, 1, 1, 0, 0).timestamp()
                df_temp = get_data(s,e)
                df_temp = clean_data(df_temp)
            else:
                s = datetime(year, month, 1, 0, 0).timestamp()
                e = datetime(year, month+1, 1, 0, 0).timestamp()
                df_temp = get_data(s,e)
                df_temp = clean_data(df_temp)
            
            # Checks to make sure cleaned dataframe actually has any tags
            if isinstance(df_temp, pd.DataFrame) == True:
                print(str(month)+'/'+str(year) + ':  ' + str(df_temp.shape[0]))
                df = pd.concat([df,df_temp], ignore_index = True)
    return df

# %%
# Testing to make sure the above function works
df_prac = join_data_2011()
# Out:
# 4/2007:  2
# 5/2007:  3
# 8/2007:  2
# 12/2007:  3
# 1/2008:  11
# 2/2008:  11
# 3/2008:  15
# 4/2008:  5
# 6/2008:  3
# 7/2008:  1
# 8/2008:  5
# 11/2008:  1
# 12/2008:  1
# 1/2009:  3
# 2/2009:  10
# 4/2009:  2
# 5/2009:  19
# 6/2009:  51
# 7/2009:  30
# 8/2009:  39
# 9/2009:  25
# 10/2009:  18
# 11/2009:  32
# 12/2009:  16
# 4/2010:  28
# 5/2010:  22
# 6/2010:  20
# 7/2010:  15
# 8/2010:  17
# 9/2010:  12
# 10/2010:  22
# 11/2010:  9
# 12/2010:  12
# 1/2011:  21
# 2/2011:  13
# 3/2011:  5
# 4/2011:  4
# 5/2011:  2
# 6/2011:  14
# 7/2011:  782
# 8/2011:  1616
# 9/2011:  1246
# 10/2011:  1240
# 11/2011:  1043
# 12/2011:  462

# %%
df_prac.shape[0]
df_prac.tag.value_counts()
# Out:
# LCLS     5631
# FACET    1282
# Name: tag, dtype: int64

# %%
search = '<table cellpadding'
df_prac[df_prac['text'].str.startswith(search) == True]
# Out:
#     elogid                     title  \
# 26  203623  LCLS Swing Shift Summary
# 32  219142    LCLS Owl Shift Summary
# 35  218481          LCLS Owl Summary
# 39  215969        LCLS Swing Summary
# 42  214092  LCLS Swing Shift Summary
# 44  213976  LCLS Swing Shift Summary
# 49  223087    LCLS day shift summary
#
#                                                  text   tag
# 26  <table cellpadding=1 border=2 align="center">\...  LCLS
# 32  <table cellpadding=2 border=2>\n<tr>\n <td> LC...  LCLS
# 35  <table cellpadding=2 border=2>\n<tr>\n <td> LC...  LCLS
# 39  <table cellpadding=2 border=2>\n<tr>\n <td> LC...  LCLS
# 42  <table cellpadding=2 border=2 align=center>\n<...  LCLS
# 44  <table cellpadding=2 border=2 align=center>\n\...  LCLS
# 49  <table cellpadding=2 border=2>\n<tr>\n <td> LC...  LCLS

# %%
title = 'Summary'
df_prac[df_prac['title'].str.endswith(title) == True]
# Out:
#       elogid                      title  \
# 26    203623   LCLS Swing Shift Summary
# 32    219142     LCLS Owl Shift Summary
# 35    218481           LCLS Owl Summary
# 39    215969         LCLS Swing Summary
# 42    214092   LCLS Swing Shift Summary
# 44    213976   LCLS Swing Shift Summary
# 990   511689              Facet Summary
# 1112  509268              FACET Summary
# 1142  509122              FACET Summary
# 1166  509015              Facet Summary
# 1196  508909              FACET Summary
# 1199  508871              FACET Summary
# 1214  508701              FACET Summary
# 1240  508447              FACET Summary
# 1317  528348              FACET Summary
# 1521  525847              FACET Summary
# 1544  525779              FACET Summary
# 1565  525729              FACET Summary
# 1653  525496              FACET Summary
# 1685  525451              FACET Summary
# 1761  525268              FACET Summary
# 1822  523449              FACET Summary
# 1977  523083              FACET Summary
# 1999  523017              FACET Summary
# 2023  522980              FACET Summary
# 2062  522830              FACET Summary
# 2461  520296  FACET Swing Shift Summary
# 2523  520053              FACET Summary
# 2654  517578              FACET Summary
# 2686  517475              FACET Summary
# 2712  517376              FACET Summary
# 2746  517252              FACET Summary
# 3586  533745              FACET Summary
# 3714  533342              FACET Summary
# 3741  531670              FACET Summary
# 3763  531601              FACET Summary
# 3779  531530              FACET Summary
# 3784  531509              FACET Summary
# 3866  530345              FACET Summary
# 3882  530309              FACET Summary
# 4049  528840              FACET Summary
# 4084  528769              FACET Summary
# 4124  528610              FACET Summary
# 4140  528548              FACET Summary
#
#                                                    text    tag
# 26    <table cellpadding=1 border=2 align="center">\...   LCLS
# 32    <table cellpadding=2 border=2>\n<tr>\n <td> LC...   LCLS
# 35    <table cellpadding=2 border=2>\n<tr>\n <td> LC...   LCLS
# 39    <table cellpadding=2 border=2>\n<tr>\n <td> LC...   LCLS
# 42    <table cellpadding=2 border=2 align=center>\n<...   LCLS
# 44    <table cellpadding=2 border=2 align=center>\n\...   LCLS
# 990   Progress - Delivered 6.2 Hours\n\n    * Turned...  FACET
# 1112  <b>Program</b>: Match LI02 following new steer...  FACET
# 1142  Delivered: 3 hrs e- to FACET; Down: 5 hrs (DR1...  FACET
# 1166  Program:\nDelivered: 3.7hrs, Down: 4.3hr (TIU)...  FACET
# 1196  <b>Program</b>\n\nDelivered: 7hrs, Down: 1hr (...  FACET
# 1199  1. Lanny fixed the leftover confusion from pre...  FACET
# 1214  <b>Summary</b>\n\nWe performed scans of final ...  FACET
# 1240  <b>Program</b>\n\n1) Deliver stable beam at 1....  FACET
# 1317  Current state of machine: 9Hz e- to PR185, 1Hz...  FACET
# 1521  Program: (delivered 8 hrs - tuning)\n\n1. Re o...  FACET
# 1544  <b>Program</b>: (delivered 8 hrs - tuning)\n\n...  FACET
# 1565  Program    Recover from PAMM\n\nProgress    Be...  FACET
# 1653  <b>Program</b>: (delivered 8hrs)\n\n1. E203 un...  FACET
# 1685  Program       emttance/wire  studies using X-p...  FACET
# 1761  Program       phase subboosters from li11 to l...  FACET
# 1822  Program      BBA and more setpoint scans to im...  FACET
# 1977  Plan\n\n    * Pull scav stoppers\n    * Re-est...  FACET
# 1999  Delivered FACET: 9Hz beam to dump (6.8 hrs), D...  FACET
# 2023  Program      Dispersion scans for various comp...  FACET
# 2062  <b>Program</b>:\n\nRecovery from PAMM. Establi...  FACET
# 2461  No Beam at all the entire shift.\n\nFACET VVS'...  FACET
# 2523  Work to be Done on owl shift:\n* Correlation p...  FACET
# 2654  Delivered: 7.3 hrs, Down: 0.7 hrs (vac valves)...  FACET
# 2686  Delivered: 8 hrs, 9Hz e- (.8 TMIT) to FACET du...  FACET
# 2712  Scheduled FACET program shelved because of Gro...  FACET
# 2746  Program:    Recover beam from Pamm\n\nProgress...  FACET
# 3586  Epic FACET shift tonight!\n\n<b>Program</b>:\n...  FACET
# 3714  Worked on IP Dispersion\n\n    * Started with ...  FACET
# 3741  <b>Program</b>:\n\n1. BBA\n2. R12/34 measureme...  FACET
# 3763  <b>Program</b>:\n\n1. Dispersion studies with ...  FACET
# 3779  State of the machine:\nquads and sextupoles of...  FACET
# 3784  Program:\nTry to make it through SEC 20 chican...  FACET
# 3866  Program\n\n    *  Restore "pencil" beam (5E9, ...  FACET
# 3882  Ops: Hollosi, Melton\nDelivered: 4 hrs, beam r...  FACET
# 4049  Program:\nSteer / Minimize Correctors in Linac...  FACET
# 4084  Program:\nFACET chicane BBA\nChasing the 3120 ...  FACET
# 4124  Program:\n1.  Continue R12 scans\n2.  Zero 17&...  FACET
# 4140  Program:\nAperture scans\nR12 scans\n\nProgres...  FACET

# %%
df_prac.at[3741,'text']
# Out:
# '<b>Program</b>:\n\n1. BBA\n2. R12/34 measurements with x/ycors in LI17 and LI20, and B1/2/3\n3. IP WS beam size vs. QFF*\n\n<b>Progress</b>:\n\n1. Finished BBA on day shift\n2. Finished R12/34 scans with correctors and bends\n3. Started IP WS scans from QFF4-QFF6 - accepted best values for QFF5-6\n\n<b>Problems</b>:\n\n1. xcor 3086 got stuck in middle of shift. Trimmed ok. Some corrs in chicane are sluggish in CRR plots.'

# %% [markdown]
# ### Now that we have all the data we want from 2011 in db file (`elog_data_2011`). Open it and try and clean up the title and text categories
# Things to clean:
# * Make everything lower case
# * Tables in text column (tricky)

# %%
engine = create_engine('sqlite:///elog_data_2011.db')
df = pd.read_sql_table('elog_data_2011', engine)

# %%
print(df.shape[0])
df.tail()
# Out:
# 6913
#       elogid                                              title  \
# 6908  554263                Model manager hangs on "gold" stage
# 6909  554261                               BBA Round 2 complete
# 6910  554258                              Swapped 30-6 for 30-4
# 6911  554257                                 1st Round BBA done
# 6912  554250  Emittance Measurements - 9491  eV (14.673  GeV...
#
#                                                    text   tag
# 6908                                                     LCLS
# 6909                                                     LCLS
# 6910  Will LEM the change in; seems to be alright so...  LCLS
# 6911                                                     LCLS
# 6912  <table class=emittanceTable>\n<tr><th></th><th...  LCLS

# %%
df['title_and_text'] = df['title'].str.cat(df['text'], sep =" ")
df.head()
# Out:
#    elogid                                    title  \
# 0  137674          EPICS LCLS IOC heartbeat fault.
# 1  137670                       RR monitor to 2 Hz
# 2  148112                         PARANOIA Restart
# 3  145825               Errorlog re: LCLS SOLN 121
# 4  144311  Rack Location of LCLS BX01/BX02 Breaker
#
#                                                 text   tag  \
# 0                                                     LCLS
# 1  A. Prinz approves this change. Approval grante...  LCLS
# 2  PARANOIA was restarted with changes to handle ...  LCLS
# 3  15-MAY-2007 20:24:11  %CAU-E-EPICS_MSG_PEP  CM...  LCLS
# 4  As one can see from Electrical Safety label th...  LCLS
#
#                                       title_and_text
# 0                   EPICS LCLS IOC heartbeat fault.
# 1  RR monitor to 2 Hz A. Prinz approves this chan...
# 2  PARANOIA Restart PARANOIA was restarted with c...
# 3  Errorlog re: LCLS SOLN 121 15-MAY-2007 20:24:1...
# 4  Rack Location of LCLS BX01/BX02 Breaker As one...

# %%
df.tail()
# Out:
#       elogid                                              title  \
# 6908  554263                Model manager hangs on "gold" stage
# 6909  554261                               BBA Round 2 complete
# 6910  554258                              Swapped 30-6 for 30-4
# 6911  554257                                 1st Round BBA done
# 6912  554250  Emittance Measurements - 9491  eV (14.673  GeV...
#
#                                                    text   tag  \
# 6908                                                     LCLS
# 6909                                                     LCLS
# 6910  Will LEM the change in; seems to be alright so...  LCLS
# 6911                                                     LCLS
# 6912  <table class=emittanceTable>\n<tr><th></th><th...  LCLS
#
#                                          title_and_text
# 6908               Model manager hangs on "gold" stage
# 6909                              BBA Round 2 complete
# 6910  Swapped 30-6 for 30-4 Will LEM the change in; ...
# 6911                                1st Round BBA done
# 6912  Emittance Measurements - 9491  eV (14.673  GeV...

# %%
df['title'] = df['title'].str.lower()
df['text'] = df['text'].str.lower()
df.head()
# Out:
#    elogid                                    title  \
# 0  137674          epics lcls ioc heartbeat fault.
# 1  137670                       rr monitor to 2 hz
# 2  148112                         paranoia restart
# 3  145825               errorlog re: lcls soln 121
# 4  144311  rack location of lcls bx01/bx02 breaker
#
#                                                 text   tag
# 0                                                     LCLS
# 1  a. prinz approves this change. approval grante...  LCLS
# 2  paranoia was restarted with changes to handle ...  LCLS
# 3  15-may-2007 20:24:11  %cau-e-epics_msg_pep  cm...  LCLS
# 4  as one can see from electrical safety label th...  LCLS

# %%
df['text'] = df['text'].replace('\n', ' ')
df.head(50)
# Out:
#     elogid                                              title  \
# 0   137674                    EPICS LCLS IOC heartbeat fault.
# 1   137670                                 RR monitor to 2 Hz
# 2   148112                                   PARANOIA Restart
# 3   145825                         Errorlog re: LCLS SOLN 121
# 4   144311            Rack Location of LCLS BX01/BX02 Breaker
# 5   175210           LCLS laser maintenance, beam suppressed.
# 6   175209           LCLS Station L1-S feedback railed itself
# 7   191763  21-2 X-Band Klystron Bottom Coil Master/Slave ...
# 8   190602                         Energy dispersion on OTR11
# 9   190126                       LCLS laser off for the night
# 10  198235  Li21 Klystron focus supply tripping on ground ...
# 11  197011                              LCLS Operator summary
# 12  196919  Added text related to XCOR Sutter controls on ...
# 13  196365           Software Test Day Schedule: Wed Jan 16th
# 14  195691                             Day shift summary LCLS
# 15  195565             Li24 YBPM 901 read about 0.5mm offset.
# 16  194474                    L1-S jumped 90 degress in Phase
# 17  194151                             LCLS owl shift summary
# 18  193577         Klystron group Eichner to investigate 21-1
# 19  193552       * Re: RE:  Klys 21-1 tripping on overcurrent
# 20  193529                  Klys 21-1 tripping on overcurrent
# 21  209848  LCLS BC1 LIONs house keeping voltages changed ...
# 22  208067  LCLS beam is taken off from KLys 24-5,6,7 and ...
# 23  206264                     PSC to PSC2 for LI22 thru LI28
# 24  205040    LI21-LI30 QE Magnet Absolute Tolerances changed
# 25  204822   Klys 25-7, 25-8 show no trigger after micro IPL.
# 26  203623                           LCLS Swing Shift Summary
# 27  202755                                 LCLS software Day.
# 28  202552  Tom Graul & Co. ready to change out the pump b...
# 29  201589  Instrument tech to clean the roto meter for LI...
# 30  201513    PEM to spray some switch on quads sector 28-30.
# 31  201506  Bill choate group to take a look at the flow s...
# 32  219142                             LCLS Owl Shift Summary
# 33  219148                                QM13 off its config
# 34  219144                                     LCLS RF issues
# 35  218481                                   LCLS Owl Summary
# 36  218421  PEM report T-20 inside Modulator for 25-3 is s...
# 37  217193           21-2 X-Band RF Amplitude Jitter Reported
# 38  216329             PEM to reset Modulators 24-6 and 25-4.
# 39  215969                                 LCLS Swing Summary
# 40  215900                             LCLS elog not printing
# 41  214443                                       LCLS summary
# 42  214092                           LCLS Swing Shift Summary
# 43  214059                                Swing Shift Program
# 44  213976                           LCLS Swing Shift Summary
# 45  213953                               Beam to spectrometer
# 46  213939                   Changes to LCLS magnet functions
# 47  223258                                 LCLS fbks shut off
# 48  223255                            LCLS fbks found running
# 49  223087                             LCLS day shift summary
#
#                                                  text   tag
# 0                                                      LCLS
# 1   A. Prinz approves this change. Approval grante...  LCLS
# 2   PARANOIA was restarted with changes to handle ...  LCLS
# 3   15-MAY-2007 20:24:11  %CAU-E-EPICS_MSG_PEP  CM...  LCLS
# 4   As one can see from Electrical Safety label th...  LCLS
# 5                                                      LCLS
# 6   Railed the I&Q values so L1-S Ampl went to zer...  LCLS
# 7   They are off on control failure showing phase ...  LCLS
# 8                                                      LCLS
# 9   Outgassing due to processing 21-1 is causing V...  LCLS
# 10     PEM Snowberger couldn't find anything wrong.\n  LCLS
# 11  Just before 9:00 Stefanie made a 117.6 ns timi...  LCLS
# 12  On the Injector Laser display I added the text...  LCLS
# 13  Software Testing Schedules for Wednesday 9/16/...  LCLS
# 14  1)  Worked onwire scanners in LI28.  More work...  LCLS
# 15    May be that quad 901 is misaligned.\nArtemised.  LCLS
# 16  Unable to contact Akre, trying other RF experts\n  LCLS
# 17  Performed emittance scans on OTR12 using xcor ...  LCLS
# 18  AMRF and PEM request Eichner to look at the wa...  LCLS
# 19  AMRF Clive O'Connor coming in to assess possib...  LCLS
# 20  PEM reports klys is gassy or somehow degraded ...  LCLS
# 21  Apparently from work today. New pedestal readi...  LCLS
# 22                  Energy feedback is working now.\n  LCLS
# 23  \nI created mini-edit files for LI22 through L...  LCLS
# 24  Nancy Spencer modified the LI21-LI30 QE Magnet...  LCLS
# 25                  Re-init PDU cleared it for now.\n  LCLS
# 26  <table cellpadding=1 border=2 align="center">\...  LCLS
# 27  http://lcls-dev/tiki-index.php?page=SoftwareDa...  LCLS
# 28                               LCLS beam to TD11.\n  LCLS
# 29  This is for quads flow switch problem. They ar...  LCLS
# 30                                                     LCLS
# 31                                                     LCLS
# 32  <table cellpadding=2 border=2>\n<tr>\n <td> LC...  LCLS
# 33  Found it was over 4 kG-m off BCON.  Put CON->D...  LCLS
# 34  LCLS shift summary gives an overview of the RF...  LCLS
# 35  <table cellpadding=2 border=2>\n<tr>\n <td> LC...  LCLS
# 36                It has been to put into maintenance  LCLS
# 37  I scoped it and saw nothing jittery including ...  LCLS
# 38  24-6 with cable fault.\n25-4 waveguide water f...  LCLS
# 39  <table cellpadding=2 border=2>\n<tr>\n <td> LC...  LCLS
# 40  You can make manual entries but images will no...  LCLS
# 41  Performed Free-Fun Weekend scans and laser mai...  LCLS
# 42  <table cellpadding=2 border=2 align=center>\n<...  LCLS
# 43  The goal tonight is to improve the emittance. ...  LCLS
# 44  <table cellpadding=2 border=2 align=center>\n\...  LCLS
# 45  The orbit after BC1 currently needs work, and ...  LCLS
# 46  From now on, when we perturb or trim LCLS magn...  LCLS
# 47  Control system seems to be restored to the LCL...  LCLS
# 48  Controls informed MCC that some LCLS feedbacks...  LCLS
# 49  <table cellpadding=2 border=2>\n<tr>\n <td> LC...  LCLS

# %%
title = 'summary'
df[df['title'].str.endswith(title) == True].head(50)
# Out:
#       elogid                                 title  \
# 11    197011                 lcls operator summary
# 17    194151                lcls owl shift summary
# 26    203623              lcls swing shift summary
# 32    219142                lcls owl shift summary
# 35    218481                      lcls owl summary
# 39    215969                    lcls swing summary
# 41    214443                          lcls summary
# 42    214092              lcls swing shift summary
# 44    213976              lcls swing shift summary
# 49    223087                lcls day shift summary
# 50    220884                lcls day shift summary
# 416   428750  current emittance and tuning summary
# 770   514597                            md summary
# 963   511774                         facet summary
# 990   511689                         facet summary
# 1023  511531                         facet summary
# 1042  511447                         facet summary
# 1078  509414        facet new crew weekend summary
# 1089  509382                         facet summary
# 1112  509268                         facet summary
# 1122  509237                         facet summary
# 1142  509122                         facet summary
# 1156  509095                         facet summary
# 1166  509015                         facet summary
# 1196  508909                         facet summary
# 1199  508871                         facet summary
# 1214  508701                         facet summary
# 1240  508447                         facet summary
# 1317  528348                         facet summary
# 1521  525847                         facet summary
# 1544  525779                         facet summary
# 1565  525729                         facet summary
# 1653  525496                         facet summary
# 1685  525451                         facet summary
# 1733  525323                     facet owl summary
# 1761  525268                         facet summary
# 1797  523477                         facet summary
# 1808  523459               injector tuning summary
# 1822  523449                         facet summary
# 1875  523313                     facet owl summary
# 1916  523245               facet day shift summary
# 1937  523184                         facet summary
# 1977  523083                         facet summary
# 1999  523017                         facet summary
# 2023  522980                         facet summary
# 2034  522887                         facet summary
# 2062  522830                         facet summary
# 2428  520415                         facet summary
# 2461  520296             facet swing shift summary
# 2523  520053                         facet summary
#
#                                                    text    tag
# 11    just before 9:00 stefanie made a 117.6 ns timi...   LCLS
# 17    performed emittance scans on otr12 using xcor ...   LCLS
# 26    <table cellpadding=1 border=2 align="center">\...   LCLS
# 32    <table cellpadding=2 border=2>\n<tr>\n <td> lc...   LCLS
# 35    <table cellpadding=2 border=2>\n<tr>\n <td> lc...   LCLS
# 39    <table cellpadding=2 border=2>\n<tr>\n <td> lc...   LCLS
# 41    performed free-fun weekend scans and laser mai...   LCLS
# 42    <table cellpadding=2 border=2 align=center>\n<...   LCLS
# 44    <table cellpadding=2 border=2 align=center>\n\...   LCLS
# 49    <table cellpadding=2 border=2>\n<tr>\n <td> lc...   LCLS
# 50    program: vault access in the morning for laser...   LCLS
# 416   these are the latest emittance measurements wh...   LCLS
# 770   1) cathode cleaning\n2) cq/sq01 scans on in20 ...   LCLS
# 963   stuff that happened:\n1. ndr bend was tripped ...  FACET
# 990   progress - delivered 6.2 hours\n\n    * turned...  FACET
# 1023  <b>program</b>\n1) otr size v. sext\n2) etax/e...  FACET
# 1042  activities in order performed:\n1. temporarily...  FACET
# 1078  <b>general program</b>: \n\n1) facet quad bba\...  FACET
# 1089  1. moved qff's in li20 to get fit-able spot on...  FACET
# 1112  <b>program</b>: match li02 following new steer...  FACET
# 1122  work done:\n- got bow-tie plots for q3e_l (lgp...  FACET
# 1142  delivered: 3 hrs e- to facet; down: 5 hrs (dr1...  FACET
# 1156  - attempted to center the beam in the facet ch...  FACET
# 1166  program:\ndelivered: 3.7hrs, down: 4.3hr (tiu)...  FACET
# 1196  <b>program</b>\n\ndelivered: 7hrs, down: 1hr (...  FACET
# 1199  1. lanny fixed the leftover confusion from pre...  FACET
# 1214  <b>summary</b>\n\nwe performed scans of final ...  FACET
# 1240  <b>program</b>\n\n1) deliver stable beam at 1....  FACET
# 1317  current state of machine: 9hz e- to pr185, 1hz...  FACET
# 1521  program: (delivered 8 hrs - tuning)\n\n1. re o...  FACET
# 1544  <b>program</b>: (delivered 8 hrs - tuning)\n\n...  FACET
# 1565  program    recover from pamm\n\nprogress    be...  FACET
# 1653  <b>program</b>: (delivered 8hrs)\n\n1. e203 un...  FACET
# 1685  program       emttance/wire  studies using x-p...  FACET
# 1733  program:\ne203 waist at ip\ne203 waist at cham...  FACET
# 1761  program       phase subboosters from li11 to l...  FACET
# 1797  <b>operating points</b>: \n2e10 nel tmit in li...  FACET
# 1808  about 2.77 tmit on the last injector toroid is...  FACET
# 1822  program      bba and more setpoint scans to im...  FACET
# 1875  <b>program</b>: (delivered: 7.7 hrs, down 0.3 ...  FACET
# 1916  progress:\n\n    * emittance tuning - unfortun...  FACET
# 1937  <b>program</b>:\n\n1. f-j decker emittance tun...  FACET
# 1977  plan\n\n    * pull scav stoppers\n    * re-est...  FACET
# 1999  delivered facet: 9hz beam to dump (6.8 hrs), d...  FACET
# 2023  program      dispersion scans for various comp...  FACET
# 2034  progress: raised current back to nominal level...  FACET
# 2062  <b>program</b>:\n\nrecovery from pamm. establi...  FACET
# 2428  there was no real program today except recover...  FACET
# 2461  no beam at all the entire shift.\n\nfacet vvs'...  FACET
# 2523  work to be done on owl shift:\n* correlation p...  FACET

# %%
df.at[120,'text']
# Out:
# '<p style="background-color: rgb(0, 0, 0);">\n<span style="color: rgb(255, 255, 255);">      | EMITX | BMAGX | EX*BX | HOURS \n--------------------------------------</span>\n<span style="color: rgb(0, 255, 0);"> OTR2 | 0.577 | 1.035 | 0.597 | 3.949  </span>\n<span style="color: rgb(0, 255, 0);"> WS12 | 0.767 | 1.062 | 0.814 | 3.840  </span>\n<span style="color: rgb(0, 255, 0);"> LI28 | 1.143 | 1.002 | 1.145 | 3.072  </span>\n<span style="color: rgb(0, 255, 0);"> LTU1 | 1.447 | 1.050 | 1.519 | 1.868  </span>\n<span style="color: rgb(255, 255, 255);">      | EMITY | BMAGY | EY*BY | HOURS \n--------------------------------------</span>\n<span style="color: rgb(0, 255, 0);"> OTR2 | 0.633 | 1.079 | 0.683 | 3.949  </span>\n<span style="color: rgb(0, 255, 0);"> WS12 | 0.484 | 1.017 | 0.492 | 3.727  </span>\n<span style="color: rgb(0, 255, 0);"> LI28 | 0.700 | 1.016 | 0.711 | 3.007  </span>\n<span style="color: rgb(0, 255, 0);"> LTU1 | 0.993 | 1.012 | 1.004 | 1.016  </span>\n</p>'

# %%
search = ['SUMMARY','Summary']
search = 'Swing'
df[df['title'].str.contains(search) == True]
# Out:
#       elogid                                              title  \
# 26    203623                           LCLS Swing Shift Summary
# 39    215969                                 LCLS Swing Summary
# 42    214092                           LCLS Swing Shift Summary
# 43    214059                                Swing Shift Program
# 44    213976                           LCLS Swing Shift Summary
# 2461  520296                          FACET Swing Shift Summary
# 2783  517123                          FACET Summary: Swingshift
# 2808  517081                               FACET Program: Swing
# 2863  516884                               FACET Program: Swing
# 2886  516751                         FACET Summary: Swingshift.
# 4200  545897             Summary of PPS Activity on Swing Shift
# 5131  539571                         Program for Swing and Owl.
# 5565  553193  LI 26 - 7 kly.s faulted. Swing PEM informed Ow...
# 6418  546539  Swing shift - put BTH and Dump in Permitted Ac...
# 6496  556891  * Re: Laser Heater position moving since Swing...
# 6498  556886     Laser Heater position moving since Swing shift
#
#                                                    text    tag
# 26    <table cellpadding=1 border=2 align="center">\...   LCLS
# 39    <table cellpadding=2 border=2>\n<tr>\n <td> LC...   LCLS
# 42    <table cellpadding=2 border=2 align=center>\n<...   LCLS
# 43    The goal tonight is to improve the emittance. ...   LCLS
# 44    <table cellpadding=2 border=2 align=center>\n\...   LCLS
# 2461  No Beam at all the entire shift.\n\nFACET VVS'...  FACET
# 2783  \n   Program: \n\n   1.)  LI20 RAD. survey by ...  FACET
# 2808  \n  Program:\n\n   1.)  LI20 RAD. survey by RF...  FACET
# 2863     1.) Continued FACET commissioning with LI10...  FACET
# 2886   Machine program was taken by Machine physics:...  FACET
# 4200  Testers: Gibbs (lead), Sampson, Otts, Sommer, ...   LCLS
# 5131  From Mike Sullivan in LCLS Physics Log.\n\nSwi...   LCLS
# 5565                                                      LCLS
# 6418                                                      LCLS
# 6496  Looks like Heater position shift was because o...   LCLS
# 6498  Looks like when the access into the injector v...   LCLS

# %%
search = '\n'
df[(df['text'].str.contains('>')) & (df['text'].str.contains('<'))].head(50)
# Out:
#      elogid                                              title  \
# 26   203623                           LCLS Swing Shift Summary
# 32   219142                             LCLS Owl Shift Summary
# 35   218481                                   LCLS Owl Summary
# 39   215969                                 LCLS Swing Summary
# 42   214092                           LCLS Swing Shift Summary
# 44   213976                           LCLS Swing Shift Summary
# 49   223087                             LCLS day shift summary
# 54   240287                SW: LCLS Magnet PS Controls Release
# 57   252453                  SW: Reboot BC1 Bunch Length IOCs-
# 67   280473    Magnet string slave units BACT out-of tol FIXED
# 68   280415  SW: Magnet release to change save/restore file...
# 74   277641        SW: Mini-Test Plan to release Magnet-R3-1-7
# 78   313038                             Emittance Measurements
# 79   312968                             Emittance Measurements
# 80   312804                       After loading design lattice
# 81   312795                             Emittance Measurements
# 82   312778                    Emittance after LEM and phasing
# 83   311188                             Emittance Measurements
# 84   311156                Emittance Measurements - LI28 & LTU
# 85   311124                             Emittance Measurements
# 86   311097                     Emittance Measurements - Final
# 87   311096       Emittance Measurements - before LTU matching
# 88   311098         Emittance Measurements after LI28 matching
# 89   311089                             Emittance Measurements
# 90   310946                             Emittance Measurements
# 91   310869                             Emittance Measurements
# 92   310842                             Emittance Measurements
# 93   310772                             Emittance Measurements
# 94   310743                             Emittance Measurements
# 95   310620                             Emittance Measurements
# 96   310423                             Emittance Measurements
# 98   323376           Emittance after flattening y orbit in L2
# 99   323372                     Emittance after matching in 28
# 100  323371                  Emittance after L2 setpoint tweak
# 101  323367                        Baseline emittance in linac
# 102  322777                             Emittance Measurements
# 103  321856                    Emittance after matching in LTU
# 104  321795                             Emittance Measurements
# 105  321784             Emittances before matching quad change
# 106  321775                             Emittance Measurements
# 107  321751         Emittance measurements before things broke
# 108  321720                             Emittance Measurements
# 109  321655                             Emittance Measurements
# 110  321648                             Emittance Measurements
# 111  321498                             Emittance Measurements
# 112  321386                      good LTU emittance and match!
# 114  321308                             Emittance Measurements
# 115  321207              emittances not great. E-loss 4.84 MeV
# 116  321019                      begin YAGXRAY data collection
# 117  319307                                     Emittances now
#
#                                                   text   tag
# 26   <table cellpadding=1 border=2 align="center">\...  LCLS
# 32   <table cellpadding=2 border=2>\n<tr>\n <td> LC...  LCLS
# 35   <table cellpadding=2 border=2>\n<tr>\n <td> LC...  LCLS
# 39   <table cellpadding=2 border=2>\n<tr>\n <td> LC...  LCLS
# 42   <table cellpadding=2 border=2 align=center>\n<...  LCLS
# 44   <table cellpadding=2 border=2 align=center>\n\...  LCLS
# 49   <table cellpadding=2 border=2>\n<tr>\n <td> LC...  LCLS
# 54   Yeserday during the ROD I booted the latest ma...  LCLS
# 57   Rebooted Bunch Length Monitor EPICS IOC in li2...  LCLS
# 67   The BACT for the following string slaves were ...  LCLS
# 68   Hello, <br />\n<br />\nThis LCLS Magnet releas...  LCLS
# 74   Hello,<br />\n<br />\nTomorrow I'd like to rel...  LCLS
# 78   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 79   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 80   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 81   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 82   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 83   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 84   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 85   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 86   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 87   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 88   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 89   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 90   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 91   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 92   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 93   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 94   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 95   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 96   So I have added the ability to print my emitta...  LCLS
# 98   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 99   <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 100  <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 101  <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 102  <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 103  <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 104  <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 105  <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 106  <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 107  <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 108  <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 109  Timestamps got scrambled.  The only new scans ...  LCLS
# 110  <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 111  <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 112  moved LTU matching QUADs by hand, in the direc...  LCLS
# 114  <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS
# 115  We need to move on and do the BFW scans, so we...  LCLS
# 116  We tried to tune up emittance as well as we co...  LCLS
# 117  <p style="background-color: rgb(0, 0, 0);">\n<...  LCLS

# %%
['Swing']
# Out:
# '<p style="background-color: rgb(0, 0, 0);">\n<span style="color: rgb(255, 255, 255);">      | EMITX | BMAGX | EX*BX | HOURS \n--------------------------------------</span>\n<span style="color: rgb(0, 255, 0);"> OTR2 | 0.573 | 1.011 | 0.579 | 0.338  </span>\n<span style="color: rgb(0, 255, 0);"> WS12 | 0.623 | 1.035 | 0.644 | 0.338  </span>\n<span style="color: rgb(0, 255, 0);"> LI28 | 1.395 | 1.025 | 1.429 | 0.338  </span>\n<span style="color: rgb(0, 255, 0);"> LTU1 | 1.920 | 1.008 | 1.935 | 0.338  </span>\n<span style="color: rgb(255, 255, 255);">      | EMITY | BMAGY | EY*BY | HOURS \n--------------------------------------</span>\n<span style="color: rgb(0, 255, 0);"> OTR2 | 0.658 | 1.008 | 0.663 | 0.338  </span>\n<span style="color: rgb(0, 255, 0);"> WS12 | 0.600 | 1.035 | 0.621 | 2.771  </span>\n<span style="color: rgb(0, 255, 0);"> LI28 | 0.791 | 1.001 | 0.791 | 0.020  </span>\n<span style="color: rgb(0, 255, 0);"> LTU1 | 1.271 | 1.008 | 1.281 | 0.338  </span>\n</p>'

# %%
text.replace("WelCome","WelCome".toUpperCase());

# %%
if df['text'].str.startswith(search) == True:

# %%
dumb = df.at[32, 'text']
dumb
# Out:
# "<table cellpadding=2 border=2>\n<tr>\n <td> lcls </td>\n <td> delivered </td>\n <td> md </td>\n <td> tuning </td>\n <td> down </td>\n <td> off</td>\n</tr>\n<tr>\n <td> - </td>\n <td> 0 </td>\n <td> 0 </td>\n <td> 8 </td>\n <td> 0 </td>\n <td> 0 </td>\n</tr>\n</table>\n\nprogram: to move l2 phase to -20' and do a ws12 scan; optimize beam to pr55.\n\nprogress:  started shift with poor beam to pr55 and by end of shift\nimproved beam to pr55.  lem, minor tweaks on linac correctors, and adding\na klystron (30-4) to give fb31 enby fbk more room, and turning on the\nli26 enby fbk all helped improve the beam on pr55 and it's stability vs.\nthe rf issues throughout the night.\n\nproblems: ws12 failed all but one scan this evening (the latest x\nemittance scan shown below).  we were plagued by rf issues which have\nsince been artemized.  these included constant trigger loss for all\nklystrons in li25, water faults on 22-5 and 29-3, cable faults on 24-6\n(bad pad requiring amrf intervention), as well as intermittent cable\nfaults on 28-7 and 28-8 - which have steadily improved over the evening\nthanks to some work by pem, and the 29-2 modulator faulted twice."

# %%
new_dumb = dumb.split('\n\nprogram:')[1]
new_dumb.replace('\n', ' ')
# Out:
# " to move l2 phase to -20' and do a ws12 scan; optimize beam to pr55.  progress:  started shift with poor beam to pr55 and by end of shift improved beam to pr55.  lem, minor tweaks on linac correctors, and adding a klystron (30-4) to give fb31 enby fbk more room, and turning on the li26 enby fbk all helped improve the beam on pr55 and it's stability vs. the rf issues throughout the night.  problems: ws12 failed all but one scan this evening (the latest x emittance scan shown below).  we were plagued by rf issues which have since been artemized.  these included constant trigger loss for all klystrons in li25, water faults on 22-5 and 29-3, cable faults on 24-6 (bad pad requiring amrf intervention), as well as intermittent cable faults on 28-7 and 28-8 - which have steadily improved over the evening thanks to some work by pem, and the 29-2 modulator faulted twice."

# %% [markdown]
# > Ultimately it get's too messy when deciding what you want to take out and what you don't. For example all emittance measurements are stored in tables but so are summaries.. Should I change that? Or leave as is?
