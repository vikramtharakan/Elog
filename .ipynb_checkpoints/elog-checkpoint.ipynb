# %% [markdown]
# # Elog Tagging
#
# The goal is to try and tag elog entries with the correct tag. In order to do this we need to:
# * Scrape the data from the entries off the elog
# * Also get the corresponding tag for entries
# * Run through NLP algorithm to try and train the entries (NOTE: Can't really do this rn because all of our tagging is kinda horseshit so we'd be training it on poop data

# %%
import pandas as pd
import numpy as np
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
import urllib

# %%
# defining the api-endpoint  
API_ENDPOINT = "https://mccelog.slac.stanford.edu/elog/wsbin/login.php"
  
# data to be sent to api 
data = {'username':config.username,
        'password':config.password}
  
# sending post request and saving response as response object 
r = requests.post(url = API_ENDPOINT, data = data) 
  
# extracting response text  
pastebin_url = r.text 
print("The pastebin URL is:%s"%pastebin_url)
# Out:
# The pastebin URL is:<html><body><h1>ELOG Login page</h1><table border=0 width=600><tr><td><p>Provide your username and password to authenticate yourself to the elog application.  Use your AFS (unix) password.  <b>If you are making an entry into a logbook for the first time, please first look at the ELOG Authorized Users link on the main elog web page or here: <A HREF="http://www.slac.stanford.edu/grp/cd/soft/elog/users/elog_authorized_users.html">ELOG Authorized Users.</A></b>  <br></td></tr><tr bgcolor=lightblue><td><table border=1><tr><form action=login.php method=POST><td width=250>username: <input name=username value="tharakan" size=15></td><td width=250>password: <input type=password name=password   size=15></td><td width=100><input type=submit name=Login value=Login></td></form></tr></table></td></tr></table></body></html>

# %%
# api-endpoint 
URL = "https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_elog_display_json.php"

# defining a params dict, for now doing something simple
PARAMS = {'logbook': 'MCC','shifts':6} 
  
# sending get request and saving the response as response object 
r = requests.get(url = URL, params = PARAMS) 
  
# extracting data in json format 
data = r.json()
data
# Out:
# [{'elogid': 1002785,
#   'title': 'DAY SHIFT SUMMARY',
#   'text': '<table CellPadding="5" BORDER=1>\n<tr>\n<th>Comment #</th>\n<th>Comment</th>\n</tr><tr><td><center>1</center></td><td>Posted Radiation signage in LI30 in front of LI29/30 gate.</td></tr>\n<tr><td><center>2</center></td><td>Lost LI21-23 search in No Access as person was able to push open shield door between LI20/21.</td></tr>\n<tr><td><center>3</center></td><td>BCS Rack in B005 was powered off, which trapped instrument techs in the lcls injector vault.  Had to let them egress out and research LCLS injector vault.</td></tr>\n<tr><td><center>4</center></td><td>Instrument techs found that Accel #1 flow switch for L0B was wired incorrectly causing our water summary faults.  They were able to fix it.</td></tr>\n</table><br>\n<br><table CellPadding=\'5\' BORDER=1><tr>\n<th>Program</th>\n<th>Delivered</th>\n<th>User Off</th>\n<th>Tuning</th>\n<th>Config &Delta;s</th>\n<th>Accl. Down</th>\n<th>Sched. Off</th>\n</tr></table><br>\n',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581119999,
#   'shift': 'Day Shift, Fri, 07-Feb-20'},
#  {'elogid': 1002784,
#   'title': 'BCS DTC commissioning not completed today, will resume Monday',
#   'text': 'There was an issue setting the low current trip point for BLRCUS. The trip should be at 2.25 GeV, but at this setting the trip does not clear unless BLRCUS is set to >2.28 GeV. Following a conversation with ADSO, Benett and Rodriguez are going to try lowering the trip setting slightly to get us to the point where the BCS trips just at BACT = 2.25 GeV.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1014,
#    'username': 'tonee',
#    'firstname': 'Tonee',
#    'lastname': 'Smith'},
#   'eventTime': 1581116165,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002782,
#   'title': 'LCLS inj searched and set to no access',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1543,
#    'username': 'tharakan',
#    'firstname': 'Vikram',
#    'lastname': 'Tharakan'},
#   'eventTime': 1581115559,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002779,
#   'title': 'Injector vault is being searched.',
#   'text': 'Waving safety inspection and interlocks as it was a brief access with no work in PPS scope.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581115141,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002781,
#   'title': 'Ops out to search LCLS Inj',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1543,
#    'username': 'tharakan',
#    'firstname': 'Vikram',
#    'lastname': 'Tharakan'},
#   'eventTime': 1581114765,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'superseded_by': 1002783,
#   'tag': 'LCLS'},
#  {'elogid': 1002777,
#   'title': 'Injector Vault Stoppers are disabled.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581114120,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002773,
#   'title': '* Re: Just had a number of alarms and warnings channels go red.  Looks like statuses are bad.  Using incident response procedure. --> Power returned to rack in B005; all affected channels back to green',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1051,
#    'username': 'hvs',
#    'firstname': 'Howard',
#    'lastname': 'Smith'},
#   'eventTime': 1581113630,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'parent': 1002763,
#   'superseded_by': 1002774,
#   'tag': 'LCLS'},
#  {'elogid': 1002774,
#   'title': 'Switch at the bottom of the rack had been set to take power away from rack 209 in MCC.  Reestablished power, everything reading back again.  * Re: Just had a number of alarms and warnings channels go red.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581113630,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'parent': 1002763,
#   'supersedes': 1002773,
#   'tag': 'LCLS'},
#  {'elogid': 1002767,
#   'title': 'Had to let techs egress out of LCLS Inj.',
#   'text': 'We lost the ability to issue hardware enables with the B005 rack power issue we believe.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581112124,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'superseded_by': 1002768,
#   'tag': 'LCLS'},
#  {'elogid': 1002768,
#   'title': 'Had to let techs egress out of LCLS Inj.',
#   'text': 'We lost the ability to issue hardware enables with the B005 rack power issue we believe.  Will research when rack has power again.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581112124,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'supersedes': 1002767,
#   'tag': 'LCLS'},
#  {'elogid': 1002766,
#   'title': 'Vik found the BCS rack in B005 is dead.  * Re: Just had a number of alarms and warnings channels go red.  Looks like statuses are bad.  Using incident response procedure.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581111757,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'parent': 1002763,
#   'tag': 'LCLS'},
#  {'elogid': 1002765,
#   'title': 'Progress on L0B water situation',
#   'text': 'Facilities Marco reports the L0B vault ACC#1 FS was wired wrong...trips when flow was sufficient, fault when sufficient.\n\nHe will enter solution information into CATER #143231.\n\nI am stuggling with this since if all of this is correct, I would expect the FS to be faulted now that we have reduced the flow back down to 4.5GPM and there is no trip. Prior to the wiring change we had no faults at ~4 GPM, and it would trip at about ~5.5 GPM.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1051,
#    'username': 'hvs',
#    'firstname': 'Howard',
#    'lastname': 'Smith'},
#   'eventTime': 1581111614,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'superseded_by': 1002780},
#  {'elogid': 1002780,
#   'title': 'Progress on L0B water situation',
#   'text': 'Facilities Marco reports the L0B vault ACC#1 FS was wired wrong...trips when flow was sufficient, okay when insufficient.\n\nHe will enter solution information into CATER #143231.\n\nI am stuggling with this since if all of this is correct, I would expect the FS to be faulted now that we have reduced the flow back down to 4.5GPM and there is no trip. Prior to the wiring change we had no faults at ~4 GPM, and it would trip at about ~5.5 GPM.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1051,
#    'username': 'hvs',
#    'firstname': 'Howard',
#    'lastname': 'Smith'},
#   'eventTime': 1581111614,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'supersedes': 1002765},
#  {'elogid': 1002763,
#   'title': 'Just had a number of alarms and warnings channels go red.  Looks like statuses are bad.  Using incident response procedure.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581110931,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'children': [1002766, 1002773, 1002774],
#   'tag': 'LCLS'},
#  {'elogid': 1002756,
#   'title': 'WD-384-022-01-C0 for L0B water flow interlocks',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1051,
#    'username': 'hvs',
#    'firstname': 'Howard',
#    'lastname': 'Smith'},
#   'eventTime': 1581108203,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'attachments': [{'attachmentid': 385928,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385928',
#     'name': 'Figure 1',
#     'filename': '20200207_124323_68511.attach_1.png',
#     'mime_type': 'Image/png'}]},
#  {'elogid': 1002760,
#   'title': 'Inj Vault -> CON.  Instrument tech to test flow switches in the vault to identify source of L0B water summary fault.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581107255,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002748,
#   'title': 'Dorking L0B water temperature setpoint to force a FS fault so Fac Instrument folks can find and fix the flowswitch.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1051,
#    'username': 'hvs',
#    'firstname': 'Howard',
#    'lastname': 'Smith'},
#   'eventTime': 1581102628,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'superseded_by': 1002749},
#  {'elogid': 1002749,
#   'title': 'Dorking L0B water temperature setpoint to force a FS fault so Fac Instrument folks can find and fix the flowswitch.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1051,
#    'username': 'hvs',
#    'firstname': 'Howard',
#    'lastname': 'Smith'},
#   'eventTime': 1581102628,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'attachments': [{'attachmentid': 385927,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385927',
#     'name': 'Figure 1',
#     'filename': '20200207_111043_51010.attach_1.png',
#     'mime_type': 'Image/png'}],
#   'supersedes': 1002748},
#  {'elogid': 1002747,
#   'title': 'Peter will be final OK to resume RF processing.',
#   'text': 'Wait for him to do final review before attempting to move forward with RF processing.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581101920,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002738,
#   'title': 'BSY Y/M lights off, permitted access button works',
#   'text': "Thought I'd put this out to confirm current access status.",
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581099024,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'attachments': [{'attachmentid': 385925,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385925',
#     'name': 'Figure 1',
#     'filename': '20200207_101024_39669.attach_1.png',
#     'mime_type': 'Image/png'}],
#   'tag': 'LCLS'},
#  {'elogid': 1002736,
#   'title': 'Finished * Re: Ops going to search LI21-23',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581098779,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'parent': 1002723,
#   'tag': 'LCLS'},
#  {'elogid': 1002723,
#   'title': 'Ops going to search LI21-23',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581093158,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'children': [1002736],
#   'tag': 'LCLS'},
#  {'elogid': 1002720,
#   'title': 'Was going to go up to RF Ready, but LI21-23 search was blown at 08:00 this morning by someone going through FACET/LI21 chicane.',
#   'text': 'Somebody decided they wanted to go through the shield door AND gate.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581092644,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'attachments': [{'attachmentid': 385923,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385923',
#     'name': 'Figure 1',
#     'filename': '20200207_082404_19498.attach_1.png',
#     'mime_type': 'Image/png'},
#    {'attachmentid': 385924,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385924',
#     'name': 'Figure 2',
#     'filename': '20200207_082404_19498.attach_2.png',
#     'mime_type': 'Image/png'}],
#   'tag': 'LCLS'},
#  {'elogid': 1002719,
#   'title': 'Posting finished.  Schuh completing linac east odd sector keybank, then enabling injector stoppers.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581092252,
#   'shift': 'Day Shift, Fri, 07-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002716,
#   'title': 'MCC Shift Change: Day Shift, Friday, 07-Feb-2020',
#   'text': 'LCLS: RF Procssing of injector stations, possible BSY IAT activities',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581091200,
#   'shift': 'Day Shift, Fri, 07-Feb-20'},
#  {'elogid': 1002715,
#   'title': 'RP and Schuh posting radiation signage in front of Sector 29/30 gate on 30 side.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581090884,
#   'shift': 'Owl Shift, Fri, 07-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002605,
#   'title': 'Plan for Friday am',
#   'text': 'RPFO will be here at 7:30am asking to access S30 to post survey boundary signs (in preparation for beam).',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1004,
#    'username': 'schuh',
#    'firstname': 'Peter',
#    'lastname': 'Schuh'},
#   'eventTime': 1581087638,
#   'shift': 'Owl Shift, Fri, 07-Feb-20',
#   'superseded_by': 1002606,
#   'tag': 'LCLS'},
#  {'elogid': 1002606,
#   'title': 'Plan for Friday am',
#   'text': "RPFO will be here at 7:30am asking to access S30 to post survey boundary signs (in preparation for beam).\n\nLet's do this before we turn on RF.",
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1004,
#    'username': 'schuh',
#    'firstname': 'Peter',
#    'lastname': 'Schuh'},
#   'eventTime': 1581087638,
#   'shift': 'Owl Shift, Fri, 07-Feb-20',
#   'supersedes': 1002605,
#   'superseded_by': 1002675,
#   'tag': 'LCLS'},
#  {'elogid': 1002675,
#   'title': 'Plan for Friday am',
#   'text': "RPFO will be here at 7:30am asking to access S30 to post survey boundary signs (in preparation for beam).\n\nLet's do this before we turn on RF.\n\nI'll be in by 7:30am.",
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1004,
#    'username': 'schuh',
#    'firstname': 'Peter',
#    'lastname': 'Schuh'},
#   'eventTime': 1581087638,
#   'shift': 'Owl Shift, Fri, 07-Feb-20',
#   'supersedes': 1002606,
#   'tag': 'LCLS'},
#  {'elogid': 1002694,
#   'title': 'SWING SHIFT SUMMARY',
#   'text': '<table CellPadding="5" BORDER=1>\n<tr>\n<th>Comment #</th>\n<th>Comment</th>\n</tr><tr><td><center>1</center></td><td>RF Processing of injector stations. Were able to process L0A and TCAV0 to nominal amplitudes with decent vacuum levels, but L0B repeatedly tripped on WSF. Were unable to resolve this issue, and proceeded to Gun RF processing. Began encountering vacuum spikes that tripped off Gun RF at ~ 5 MW power. </td></tr>\n</table><br>\n<br><table CellPadding=\'5\' BORDER=1><tr>\n<th>Program</th>\n<th>Delivered</th>\n<th>User Off</th>\n<th>Tuning</th>\n<th>Config &Delta;s</th>\n<th>Accl. Down</th>\n<th>Sched. Off</th>\n</tr><tr><td>Inj_user</td><td><center>8.0</center></td><td><center>0.0</center></td><td><center>0.0</center></td><td><center>0.0</center></td><td><center>0.0</center></td><td><center></center></td><tr><td>SPEAR_user</td><td><center>8.0</center></td><td><center>0.0</center></td><td><center>0.0</center></td><td><center>0.0</center></td><td><center>0.0</center></td><td><center></center></td></table><br>\n',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1446,
#    'username': 'aosman',
#    'firstname': 'Ahmed',
#    'lastname': 'Osman'},
#   'eventTime': 1581062399,
#   'shift': 'Swing Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002697,
#   'title': 'Disabled PPS Ignition, Cyboxes, and audio alarms.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1446,
#    'username': 'aosman',
#    'firstname': 'Ahmed',
#    'lastname': 'Osman'},
#   'eventTime': 1581060866,
#   'shift': 'Swing Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002696,
#   'title': 'East Odd Sector key in ACR red keysafe.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1446,
#    'username': 'aosman',
#    'firstname': 'Ahmed',
#    'lastname': 'Osman'},
#   'eventTime': 1581060847,
#   'shift': 'Swing Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002695,
#   'title': 'Inj Vault Stoppers disabled.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1446,
#    'username': 'aosman',
#    'firstname': 'Ahmed',
#    'lastname': 'Osman'},
#   'eventTime': 1581060145,
#   'shift': 'Swing Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002693,
#   'title': 'Linac East -> Zone Entry',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1446,
#    'username': 'aosman',
#    'firstname': 'Ahmed',
#    'lastname': 'Osman'},
#   'eventTime': 1581059533,
#   'shift': 'Swing Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002692,
#   'title': 'AMRF done for the night. Put in Gun Valve, opened PPS contactors for Inj Modulators, and turned off VVS10.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1446,
#    'username': 'aosman',
#    'firstname': 'Ahmed',
#    'lastname': 'Osman'},
#   'eventTime': 1581059445,
#   'shift': 'Swing Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002691,
#   'title': 'Summary of Gun RF Processing',
#   'text': 'RF Power got up to ~ 5MW (25 MW nominal)  before vacuum spikes began tripping gun valves in--more processing definitely needed. ',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1446,
#    'username': 'aosman',
#    'firstname': 'Ahmed',
#    'lastname': 'Osman'},
#   'eventTime': 1581059281,
#   'shift': 'Swing Shift, Thu, 06-Feb-20',
#   'attachments': [{'attachmentid': 385915,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385915',
#     'name': 'Figure 1',
#     'filename': '20200206_230801_85513.attach_1.png',
#     'mime_type': 'Image/png'}]},
#  {'elogid': 1002690,
#   'title': 'Gun valve 155 went in again--pulling valve',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1068,
#    'username': 'sommer',
#    'firstname': 'Tom',
#    'lastname': 'Sommer'},
#   'eventTime': 1581058390,
#   'shift': 'Swing Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002689,
#   'title': 'Gun valve 155 went in and we pulled it',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1068,
#    'username': 'sommer',
#    'firstname': 'Tom',
#    'lastname': 'Sommer'},
#   'eventTime': 1581055281,
#   'shift': 'Swing Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002688,
#   'title': "R Kelly is processing gun--says he will start applying RF (haven't seenevidence of this yet)",
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1068,
#    'username': 'sommer',
#    'firstname': 'Tom',
#    'lastname': 'Sommer'},
#   'eventTime': 1581051454,
#   'shift': 'Swing Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002686,
#   'title': 'Mod HV on! Was indeed the thyratron heater timeout keeping us off. * Re: Some trouble getting Gun turned on--hopefully resolved.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1446,
#    'username': 'aosman',
#    'firstname': 'Ahmed',
#    'lastname': 'Osman'},
#   'eventTime': 1581049805,
#   'shift': 'Swing Shift, Thu, 06-Feb-20',
#   'parent': 1002685,
#   'superseded_by': 1002687},
#  {'elogid': 1002687,
#   'title': 'Gun Mod HV on! Was indeed the thyratron heater timeout keeping us off. * Re: Some trouble getting Gun turned on--hopefully resolved.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1446,
#    'username': 'aosman',
#    'firstname': 'Ahmed',
#    'lastname': 'Osman'},
#   'eventTime': 1581049805,
#   'shift': 'Swing Shift, Thu, 06-Feb-20',
#   'parent': 1002685,
#   'supersedes': 1002686},
#  {'elogid': 1002685,
#   'title': 'Some trouble getting Gun turned on--hopefully resolved.',
#   'text': 'Spent some time on NIRP tests before getting to the Gun. Thyratron heater began timing out (30 min) for some reason, which took us some time to realize. we are hoping this is the final interlock needed for gun turn on. ',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1446,
#    'username': 'aosman',
#    'firstname': 'Ahmed',
#    'lastname': 'Osman'},
#   'eventTime': 1581049439,
#   'shift': 'Swing Shift, Thu, 06-Feb-20',
#   'children': [1002687, 1002686]},
#  {'elogid': 1002683,
#   'title': '* Re: Several MPS faults need to be addressed before running beam --> one down, some to go',
#   'text': 'We were able to clear the LI21 MMG TIU fault by juicing the gauge locally at station 21-5.\n\nThe issue with the MCC Emergency Radiation Stopper is particularly puzzling. I could only find two instances in the ELOG about this, one of the signal being set to Always Evaluate, and another where it was referenced in a summary entry following a winter closure (https://mccelog.slac.stanford.edu/elog/wbin/elog_item.php?elog_id=757253), without resolution or CATER, implying that the issue resolved itself. \n\nLooking through the archive we can see that the latch status is normally OK during running, but whenever we have an extended planned downtime or are doing PPS certification the signal drops to IS_NOT_OK. I was not able to find any association with obvious PPS related items like the ignition, any stoppers or BSOICs, or access states. It seems to just neatly go away during planned shut down periods and come back just before they end, yet I am unable to place exactly which signal controls it. ',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1449,
#    'username': 'loney',
#    'firstname': 'Ryan',
#    'lastname': 'Loney'},
#   'eventTime': 1581048279,
#   'shift': 'Swing Shift, Thu, 06-Feb-20',
#   'parent': 1002673,
#   'tag': 'LCLS'},
#  {'elogid': 1002682,
#   'title': 'Unfortunately no luck with tracking down L0B WSF flowswitch, will CATER and leave for the morning. Calling Feng and moving on to Gun processing.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1446,
#    'username': 'aosman',
#    'firstname': 'Ahmed',
#    'lastname': 'Osman'},
#   'eventTime': 1581044418,
#   'shift': 'Swing Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002681,
#   'title': 'Working with Rick Kelly to try and determine which flow switch is responsible for the L0B WSF.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1446,
#    'username': 'aosman',
#    'firstname': 'Ahmed',
#    'lastname': 'Osman'},
#   'eventTime': 1581043411,
#   'shift': 'Swing Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002676,
#   'title': '* Re: Clarification on the L0B flow switch saga',
#   'text': 'This is information from 2014 which could be useful in 2024',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1051,
#    'username': 'hvs',
#    'firstname': 'Howard',
#    'lastname': 'Smith'},
#   'eventTime': 1581039634,
#   'shift': 'Swing Shift, Thu, 06-Feb-20',
#   'parent': 754965,
#   'tag': 'LCLS'},
#  {'elogid': 1002674,
#   'title': 'Curiously, as we turn up L0B the water flow increases (as expected) but as the flow increases we get a flowswitch trip.',
#   'text': 'Seems like a really cruel joke.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1051,
#    'username': 'hvs',
#    'firstname': 'Howard',
#    'lastname': 'Smith'},
#   'eventTime': 1581039086,
#   'shift': 'Swing Shift, Thu, 06-Feb-20',
#   'attachments': [{'attachmentid': 385913,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385913',
#     'name': 'Figure 1',
#     'filename': '20200206_173126_22115.attach_1.png',
#     'mime_type': 'Image/png'},
#    {'attachmentid': 385914,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385914',
#     'name': 'Figure 2',
#     'filename': '20200206_173126_22115.attach_2.png',
#     'mime_type': 'Image/png'}]},
#  {'elogid': 1002673,
#   'title': '* Re: Several MPS faults need to be addressed before running beam.',
#   'text': 'An MPS unlatch all command cleared the PIC faults - the "HV OFF" readback on the PIC Chassis EDM panel was a red herring.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1301,
#    'username': 'mgibbs',
#    'firstname': 'Matt',
#    'lastname': 'Gibbs'},
#   'eventTime': 1581038947,
#   'shift': 'Swing Shift, Thu, 06-Feb-20',
#   'children': [1002683],
#   'parent': 1002665,
#   'tag': 'LCLS'},
#  {'elogid': 1002672,
#   'title': 'Trying to understand frequent 20-8 L0B water flow switch faults',
#   'text': 'We see "Water Summary Faults" on 20-8...not indicating which flow switch is actually tripping.\n\nThe water readbacks for L0A 20-7 look normal compared to Dec 2018 values (which were 19.5 GPM regulation control valve 64 percent).\n\nThe water readbacks for L0B 20-8 look different compared to Dec 2018 values: (which were 11 GPM regulation control valve 16 percent).\n\nIt would seem like this is since the average power load for L0B is low. The RF forward power is still low compared to nominal 25MW (nominal 50MW).',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1051,
#    'username': 'hvs',
#    'firstname': 'Howard',
#    'lastname': 'Smith'},
#   'eventTime': 1581037730,
#   'shift': 'Swing Shift, Thu, 06-Feb-20',
#   'attachments': [{'attachmentid': 385911,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385911',
#     'name': 'Figure 1',
#     'filename': '20200206_170850_17763.attach_1.png',
#     'mime_type': 'Image/png'},
#    {'attachmentid': 385912,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385912',
#     'name': 'Figure 2',
#     'filename': '20200206_170850_17763.attach_2.png',
#     'mime_type': 'Image/png'}]},
#  {'elogid': 1002671,
#   'title': '20-8 keeps tripping on Water Summary Fault.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1446,
#    'username': 'aosman',
#    'firstname': 'Ahmed',
#    'lastname': 'Osman'},
#   'eventTime': 1581037263,
#   'shift': 'Swing Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002670,
#   'title': "Rick's walking up TCAV0",
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1500,
#    'username': 'zacarias',
#    'firstname': 'Lisa',
#    'lastname': 'Zacarias'},
#   'eventTime': 1581037191,
#   'shift': 'Swing Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002666,
#   'title': 'Harms out in S26 to troubleshoot crate 1 bus verifier',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1500,
#    'username': 'zacarias',
#    'firstname': 'Lisa',
#    'lastname': 'Zacarias'},
#   'eventTime': 1581034547,
#   'shift': 'Swing Shift, Thu, 06-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002669,
#   'title': 'MCC Shift Change: Swing Shift, Thursday, 06-Feb-2020',
#   'text': 'Continue RF processing. Hopefully move onto gun processing. ',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1446,
#    'username': 'aosman',
#    'firstname': 'Ahmed',
#    'lastname': 'Osman'},
#   'eventTime': 1581033600,
#   'shift': 'Swing Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002658,
#   'title': 'DAY SHIFT SUMMARY',
#   'text': '<table CellPadding="5" BORDER=1>\n<tr>\n<th>Comment #</th>\n<th>Comment</th>\n</tr><tr><td><center>1</center></td><td>RF Processing of Injector stations L0A and L0B.</td></tr>\n<tr><td><center>2</center></td><td>Injector Cooling System (ICS) was not regulating.  Temperature incresaed due to having L0A on and starved L0B for water causing water summary fault.  It was found that a valve regulating CT1202 water to heat exchanger for ICS was not enabled.  Facilities got it on and working again (~3.7 hr down).  </td></tr>\n</table><br>\n<br><table CellPadding=\'5\' BORDER=1><tr>\n<th>Program</th>\n<th>Delivered</th>\n<th>User Off</th>\n<th>Tuning</th>\n<th>Config &Delta;s</th>\n<th>Accl. Down</th>\n<th>Sched. Off</th>\n</tr><tr><td>Inj_user</td><td><center>7.7</center></td><td><center>0.0</center></td><td><center>0.0</center></td><td><center>0.0</center></td><td><center>0.3</center></td><td><center></center></td><tr><td>LCLS-MD</td><td><center>4.3</center></td><td><center>0.0</center></td><td><center>0.0</center></td><td><center>0.0</center></td><td><center>3.7</center></td><td><center>0</center></td><tr><td>SPEAR_user</td><td><center>8.0</center></td><td><center>0.0</center></td><td><center>0.0</center></td><td><center>0.0</center></td><td><center>0.0</center></td><td><center></center></td></table><br>\n',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581033599,
#   'shift': 'Day Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002664,
#   'title': 'Several MPS faults need to be addressed before running beam.',
#   'text': 'MCC Emergency Radiation Stopper: I think this is supposed to be for the big red button, but that is currently reset and should be OK.\nPIC Raw Charge Thresholds IN20 and BLM/PIC Watchdog Upstream of TDUND: The PIC chassis in IN20 doesn\'t have HV power, even though the high voltage "ON" button is pressed in EPICS.\nMain Manifold Gauge LI21 Station 5: (Probably bypass-able) The main manifold gauge is reporting a normal pressure, but has a fault.  I am not sure how to reset this fault, there is no EPICS control as far as I know.\nToroid Comparator Inj Spectrometer Broken: This might fix itself once the toroids see beam, but this toroid comparator is currently in a "broken" state.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1301,
#    'username': 'mgibbs',
#    'firstname': 'Matt',
#    'lastname': 'Gibbs'},
#   'eventTime': 1581033556,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'superseded_by': 1002665,
#   'tag': 'LCLS'},
#  {'elogid': 1002665,
#   'title': 'Several MPS faults need to be addressed before running beam.',
#   'text': 'MCC Emergency Radiation Stopper: I think this is supposed to be for the big red button, but that is currently reset and should be OK.\n\nPIC Raw Charge Thresholds IN20 and BLM/PIC Watchdog Upstream of TDUND: The PIC chassis in IN20 doesn\'t have HV power, even though the high voltage "ON" button is pressed in EPICS.\n\nMain Manifold Gauge LI21 Station 5: (Probably bypass-able) The main manifold gauge is reporting a normal pressure, but has a fault.  I am not sure how to reset this fault, there is no EPICS control as far as I know.\n\nToroid Comparator Inj Spectrometer Broken: This might fix itself once the toroids see beam, but this toroid comparator is currently in a "broken" state.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1301,
#    'username': 'mgibbs',
#    'firstname': 'Matt',
#    'lastname': 'Gibbs'},
#   'eventTime': 1581033556,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'children': [1002673],
#   'supersedes': 1002664,
#   'tag': 'LCLS'},
#  {'elogid': 1002663,
#   'title': "Bypassed all 'VVS Circuit Breaker' MPS faults for one week.",
#   'text': "These are zero-rating the gun, but are not relevant in our spectrometer-only operating mode.  I'm bypassing all of them for one week.",
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1301,
#    'username': 'mgibbs',
#    'firstname': 'Matt',
#    'lastname': 'Gibbs'},
#   'eventTime': 1581032840,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002647,
#   'title': 'AMRF to continue processing.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581027151,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002645,
#   'title': 'Valve problem has been fixed.',
#   'text': 'It was found that the feedback for the mixing valve in front of heat exchanger for ICS was disabled.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581027113,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'superseded_by': 1002646,
#   'tag': 'LCLS'},
#  {'elogid': 1002644,
#   'title': 'Injector water looks much better now',
#   'text': 'Facilities found a control valve on the tower side of the ICS heat exchanger whose control programming had it disabled.\nIt got re-enabled and is under actuation in manual, and the ICS water temperature is coming back into regulation now.\nThey will try to get the tower valve back into auto...',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1051,
#    'username': 'hvs',
#    'firstname': 'Howard',
#    'lastname': 'Smith'},
#   'eventTime': 1581026738,
#   'shift': 'Day Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002637,
#   'title': 'RSWCF 7756 -> Work Approved',
#   'text': 'This is to jumper input signal to provide "Machine Off" status.  Requirements are same as other WCFs, VVS 11-15 off, stoppers 950 & 960 blocked in, and BX01/02 locked off.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581024311,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'superseded_by': 1002638,
#   'highPriority': True,
#   'tag': 'LCLS'},
#  {'elogid': 1002638,
#   'title': 'RSWCF 7756 -> Work Approved',
#   'text': 'This is to jumper input signal to BSY PPS to provide "Machine Off" status.  Requirements are same as other WCFs, VVS 11-15 off, stoppers 950 & 960 blocked in, and BX01/02 locked off.  This is necessary to continue with BSY PPS testing while in Beam Permit.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581024311,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'supersedes': 1002637,
#   'highPriority': True,
#   'tag': 'LCLS'},
#  {'elogid': 1002636,
#   'title': 'FAC sending instrument tech out to investigate.  Most likely theory currently is that ICS heat exchanger for CT 1202 is not doing its job properly.  Perhaps valve issue.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581021145,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'superseded_by': 1002641,
#   'tag': 'LCLS'},
#  {'elogid': 1002641,
#   'title': 'FOC sending instrument tech out to investigate.  Most likely theory currently is that ICS heat exchanger for CT 1202 is not doing its job properly.  Perhaps valve issue.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581021145,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'supersedes': 1002636,
#   'tag': 'LCLS'},
#  {'elogid': 1002626,
#   'title': 'Here is what we think is going on with the injector RF water.',
#   'text': 'L0A runup to full amplitude went well. \nL0B started run up and we got into temperature problems....and L0B water flow switch faults.\nL0A was a max flow and running hot...and probably starving all of the water from L0B causing L0B water faults (which we cannot figure out which specific switch is tripping).\n\nReal problem is the ICS (erroneously called "from sector 20 accelerator water on EDM)  supply water started heating up. Normally this runs/regulates at 109 degF with all three stations running full.\nWhen we turned on L0A and ran it up, this water got hot, calling for L0A control to hog more water.\n\nWe have had AMRF turn L0A AMPL down by half to get things from running away. \n\nWe are asking Facilities to investigate why we don\'t seem to be getting any heat out of the LCLS ICS water system.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1051,
#    'username': 'hvs',
#    'firstname': 'Howard',
#    'lastname': 'Smith'},
#   'eventTime': 1581017659,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'attachments': [{'attachmentid': 385903,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385903',
#     'name': 'Figure 1',
#     'filename': '20200206_113419_101176.attach_1.png',
#     'mime_type': 'Image/png'},
#    {'attachmentid': 385904,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385904',
#     'name': 'Figure 2',
#     'filename': '20200206_113419_101176.attach_2.png',
#     'mime_type': 'Image/png'}]},
#  {'elogid': 1002622,
#   'title': 'Injector RF Processing and run up procedure from AMRF',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1051,
#    'username': 'hvs',
#    'firstname': 'Howard',
#    'lastname': 'Smith'},
#   'eventTime': 1581016789,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'attachments': [{'attachmentid': 385902,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385902',
#     'name': 'Figure 1',
#     'filename': '20200206_111949_98436.attach_1.pdf',
#     'mime_type': 'application/pdf'}]},
#  {'elogid': 1002617,
#   'title': 'Water/temperature issues with Injector RF ramp up',
#   'text': 'L0B has a water summary fault but none of the standard flowswitches report tripped.\n\nL0A running with more flow than normal operation, temperature regulation valve maxed out, and load temperature on the rise.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1051,
#    'username': 'hvs',
#    'firstname': 'Howard',
#    'lastname': 'Smith'},
#   'eventTime': 1581015102,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'attachments': [{'attachmentid': 385896,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385896',
#     'name': 'Figure 1',
#     'filename': '20200206_105142_93145.attach_1.png',
#     'mime_type': 'Image/png'},
#    {'attachmentid': 385897,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385897',
#     'name': 'Figure 2',
#     'filename': '20200206_105142_93145.attach_2.png',
#     'mime_type': 'Image/png'},
#    {'attachmentid': 385898,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385898',
#     'name': 'Figure 3',
#     'filename': '20200206_105142_93145.attach_3.png',
#     'mime_type': 'Image/png'}],
#   'superseded_by': 1002618},
#  {'elogid': 1002618,
#   'title': 'Water/temperature issues with Injector RF ramp up',
#   'text': 'L0B has a water summary fault but none of the standard flowswitches report tripped.\n\nL0A running with more flow than normal operation, temperature regulation valve maxed out, and load temperature on the rise.\n\nAdd to that confusion that Facilities has secured 20 ACS LCW pump (used for FACET magnets), and we think LCLS IV does not use this water, even though some EPICS displays indicated that it does.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1051,
#    'username': 'hvs',
#    'firstname': 'Howard',
#    'lastname': 'Smith'},
#   'eventTime': 1581015102,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'attachments': [{'attachmentid': 385899,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385899',
#     'name': 'Figure 1',
#     'filename': '20200206_105407_93561.attach_1.png',
#     'mime_type': 'Image/png'},
#    {'attachmentid': 385900,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385900',
#     'name': 'Figure 2',
#     'filename': '20200206_105407_93561.attach_2.png',
#     'mime_type': 'Image/png'},
#    {'attachmentid': 385901,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385901',
#     'name': 'Figure 3',
#     'filename': '20200206_105407_93561.attach_3.png',
#     'mime_type': 'Image/png'}],
#   'supersedes': 1002617},
#  {'elogid': 1002616,
#   'title': 'FAC pointed out that ACS pump is off, L0A is too hot.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581014543,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'attachments': [{'attachmentid': 385895,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385895',
#     'name': 'Figure 1',
#     'filename': '20200206_104223_91388.attach_1.png',
#     'mime_type': 'Image/png'}],
#   'tag': 'LCLS'},
#  {'elogid': 1002614,
#   'title': 'Getting water summary fault on L0B.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581013674,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002611,
#   'title': 'L0B modulator had some issues; Allan Johnson ramping up L0B amplitude now',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1534,
#    'username': 'aasaad',
#    'firstname': 'Alexander',
#    'lastname': 'Saad'},
#   'eventTime': 1581013257,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'parent': 1002601,
#   'tag': 'LCLS'},
#  {'elogid': 1002603,
#   'title': 'BSY QCUS2 looks like it can be repaired in situ',
#   'text': "Jeff Garcia assessed the QCUS2 leak and says repairing in place looks like a 4 hour job. We are keeping it on the SML in the hope that we can get a window before the Feb 18 STCLTS reinstallation window, just in case the fix doesn't work.",
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1014,
#    'username': 'tonee',
#    'firstname': 'Tonee',
#    'lastname': 'Smith'},
#   'eventTime': 1581010903,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002601,
#   'title': 'L0A forward energy up at ~37, moving on to L0B.  Vacuum looking ok.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581009898,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'children': [1002611],
#   'tag': 'LCLS'},
#  {'elogid': 1002596,
#   'title': 'Target (FTP) values for forward energy for injector stations',
#   'text': '20-5 TCAV0: Not sure have to do more research.\n20-6 RF GUN: 25.7MW...not run up yet.\n20-7 L0A: 41MW presently at about 35MW.\n20-8 L0B: 48MW not run up yet.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1051,
#    'username': 'hvs',
#    'firstname': 'Howard',
#    'lastname': 'Smith'},
#   'eventTime': 1581008535,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'attachments': [{'attachmentid': 385888,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385888',
#     'name': 'Figure 1',
#     'filename': '20200206_090215_72032.attach_1.png',
#     'mime_type': 'Image/png'},
#    {'attachmentid': 385889,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385889',
#     'name': 'Figure 2',
#     'filename': '20200206_090215_72032.attach_2.png',
#     'mime_type': 'Image/png'},
#    {'attachmentid': 385890,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385890',
#     'name': 'Figure 3',
#     'filename': '20200206_090215_72032.attach_3.png',
#     'mime_type': 'Image/png'}]},
#  {'elogid': 1002593,
#   'title': 'Brooks McCall is jumpering out the "Beam ON" signal that gets input into the BSY Zone PPS PLC.',
#   'text': 'This is in order to make access controls work and to get the Y/M lights into the yellow state.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1301,
#    'username': 'mgibbs',
#    'firstname': 'Matt',
#    'lastname': 'Gibbs'},
#   'eventTime': 1581008442,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002590,
#   'title': 'BSY workers commenting about flashing magenta lights at BSY entrance',
#   'text': 'Access for work in BSY is planned until noon.\nLINAC East CCR PPS is in Ready for Beam.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1051,
#    'username': 'hvs',
#    'firstname': 'Howard',
#    'lastname': 'Smith'},
#   'eventTime': 1581007890,
#   'shift': 'Day Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002588,
#   'title': 'L0B ampl being ramped up.  Our first vacuum spike.',
#   'text': 'They grow up so quickly.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581007390,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'attachments': [{'attachmentid': 385886,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385886',
#     'name': 'Figure 1',
#     'filename': '20200206_084310_68398.attach_1.png',
#     'mime_type': 'Image/png'}],
#   'superseded_by': 1002592,
#   'tag': 'LCLS'},
#  {'elogid': 1002592,
#   'title': 'L0A ampl being ramped up.  Our first vacuum spike.',
#   'text': 'They grow up so quickly.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581007390,
#   'shift': 'Day Shift, Thu, 06-Feb-20',
#   'attachments': [{'attachmentid': 385887,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385887',
#     'name': 'Figure 1',
#     'filename': '20200206_085903_71427.attach_1.png',
#     'mime_type': 'Image/png'}],
#   'supersedes': 1002588,
#   'tag': 'LCLS'},
#  {'elogid': 1002572,
#   'title': 'MCC Shift Change: Day Shift, Thursday, 06-Feb-2020',
#   'text': 'LCLS: Injector Station RF processing.  BSY IAT activities.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581004800,
#   'shift': 'Day Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002573,
#   'title': 'Let the gun processing commence!',
#   'text': "Spoke with A. Johnson, he's headed down to get the gun on. ",
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581003652,
#   'shift': 'Owl Shift, Thu, 06-Feb-20',
#   'superseded_by': 1002587,
#   'tag': 'LCLS'},
#  {'elogid': 1002576,
#   'title': 'Enabled PPS ignition.  Peter enabled injector vault stoppers, and returned East Odd sector key.',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1374,
#    'username': 'aegger',
#    'firstname': 'Adam',
#    'lastname': 'Egger'},
#   'eventTime': 1581003451,
#   'shift': 'Owl Shift, Thu, 06-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002574,
#   'title': 'LCLS: Rebooted Magnet Alarms, ChannelWatcher and widlcard/model ioc -CATER 141726 Job 3',
#   'text': "I've rebooted the LCLS Magnet IOC that contains pvs for the model (EACT,EDES,ECON,etc) and wildcard ctrl functions to add LCLS-II pvs.  I've also rebooted ChannelWatcher, and Magnet alarms to add LCLS-II pvs as well. If there are any issues please call me at x3417 or 650-704-1618    - Kristi",
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1037,
#    'username': 'luchini',
#    'firstname': 'Kristi',
#    'lastname': 'Luchini'},
#   'eventTime': 1581003392,
#   'shift': 'Owl Shift, Thu, 06-Feb-20'},
#  {'elogid': 1002537,
#   'title': 'Plan for Thursday am',
#   'text': 'Ia??ll be in around 7am so I can brief the morning ops on new hot sheet prior to turn on. \n',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1004,
#    'username': 'schuh',
#    'firstname': 'Peter',
#    'lastname': 'Schuh'},
#   'eventTime': 1581001216,
#   'shift': 'Owl Shift, Thu, 06-Feb-20',
#   'superseded_by': 1002538},
#  {'elogid': 1002538,
#   'title': 'Plan for Thursday am',
#   'text': 'Ia??ll be in around 7am so I can brief the morning ops on new hot sheet prior to turn on. If youa??re in before I am, please call me. \n',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1004,
#    'username': 'schuh',
#    'firstname': 'Peter',
#    'lastname': 'Schuh'},
#   'eventTime': 1581001216,
#   'shift': 'Owl Shift, Thu, 06-Feb-20',
#   'supersedes': 1002537,
#   'superseded_by': 1002539},
#  {'elogid': 1002539,
#   'title': 'Plan for Thursday am',
#   'text': 'I will be in around 7am so I can brief the morning ops on new hot sheet prior to turn on. If youa??re in before I am, please call me. \n',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1004,
#    'username': 'schuh',
#    'firstname': 'Peter',
#    'lastname': 'Schuh'},
#   'eventTime': 1581001216,
#   'shift': 'Owl Shift, Thu, 06-Feb-20',
#   'supersedes': 1002538},
#  {'elogid': 1002534,
#   'title': 'SWING SHIFT SUMMARY',
#   'text': '<table CellPadding="5" BORDER=1>\n<tr>\n<th>Comment #</th>\n<th>Comment</th>\n</tr><tr><td><center>1</center></td><td>Activated the Linac East Injector BAS.</td></tr>\n<tr><td><center>2</center></td><td>Began RF processing of the LCLS injector modulators. Ran 20-5, 20-7, and 20-8 up to their nominal beam voltage.</td></tr>\n</table><br>\n<br><table CellPadding=\'5\' BORDER=1><tr>\n<th>Program</th>\n<th>Delivered</th>\n<th>User Off</th>\n<th>Tuning</th>\n<th>Config &Delta;s</th>\n<th>Accl. Down</th>\n<th>Sched. Off</th>\n</tr></table><br>\n',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1360,
#    'username': 'bripman',
#    'firstname': 'Ben',
#    'lastname': 'Ripman'},
#   'eventTime': 1580975999,
#   'shift': 'Swing Shift, Wed, 05-Feb-20'},
#  {'elogid': 1002533,
#   'title': "Finished with Alex's shutdown script",
#   'text': '1) Save a SCORE\n2) Turn Beam Permissive off\n3) Turn off and open PPS contactors for 20-5, 20-6, 20-7, and 20-8\n4) Insert Gun/INJ Valve 155\n5) Open VVS10 breaker\n6) Insert RST1\n7) Set LINAC East PPS Global State to Zone Entry\n8) Disable LCLS Injector stoppers in Sector 20 (location LKG20-36)\n9) Leave the S20 Injector and S21-29 in No Access\n10) Disable the ACR/ANR LINAC PPS Enable (ignition) key\n11) Disable all CyBoxes and disable Audio Alarms (instructions)\n12) Log out of OPIs if SPEAR3 operator is not in ACR\n13) Inform main gate that ACR is unmanned if SPEAR3 operator is not in ACR',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1360,
#    'username': 'bripman',
#    'firstname': 'Ben',
#    'lastname': 'Ripman'},
#   'eventTime': 1580973755,
#   'shift': 'Swing Shift, Wed, 05-Feb-20'},
#  {'elogid': 1002530,
#   'title': "R. Kelly ran 20-5, 7, and 8 up to their nominal beam voltage; he's shutting them off for the night now",
#   'text': "We'll execute Alex's shutdown script once the stations are off.",
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1360,
#    'username': 'bripman',
#    'firstname': 'Ben',
#    'lastname': 'Ripman'},
#   'eventTime': 1580972320,
#   'shift': 'Swing Shift, Wed, 05-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002529,
#   'title': 'Rick Kelly ramping up L0A, L0B, and TCAV0 modulator HV',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1446,
#    'username': 'aosman',
#    'firstname': 'Ahmed',
#    'lastname': 'Osman'},
#   'eventTime': 1580971929,
#   'shift': 'Swing Shift, Wed, 05-Feb-20'},
#  {'elogid': 1002528,
#   'title': 'L0A is on!',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1360,
#    'username': 'bripman',
#    'firstname': 'Ben',
#    'lastname': 'Ripman'},
#   'eventTime': 1580970252,
#   'shift': 'Swing Shift, Wed, 05-Feb-20',
#   'attachments': [{'attachmentid': 385869,
#     'url': 'https://mccelog.slac.stanford.edu/elog/dev/mgibbs/dev_view_attachment.php?attachment_id=385869',
#     'name': 'Figure 1',
#     'filename': '20200205_222412_96882.attach_1.png',
#     'mime_type': 'Image/png'}],
#   'tag': 'LCLS'},
#  {'elogid': 1002527,
#   'title': 'Oops, injector stoppers are still disabled; Peter heading out to enable them now',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1360,
#    'username': 'bripman',
#    'firstname': 'Ben',
#    'lastname': 'Ripman'},
#   'eventTime': 1580969740,
#   'shift': 'Swing Shift, Wed, 05-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002523,
#   'title': 'East odd keybank complete, Linac East --> Ready for Beam, turning on VVS 10',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1360,
#    'username': 'bripman',
#    'firstname': 'Ben',
#    'lastname': 'Ripman'},
#   'eventTime': 1580963905,
#   'shift': 'Swing Shift, Wed, 05-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002522,
#   'title': 'Peter is returning the east odd sector key we had in the keysafe',
#   'text': 'Need that keybank complete to make up the 21-29 secure loop so we can go to Ready for RF and turn on VVS 10. The key is not associated with any currently open RSWCFs.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1360,
#    'username': 'bripman',
#    'firstname': 'Ben',
#    'lastname': 'Ripman'},
#   'eventTime': 1580963565,
#   'shift': 'Swing Shift, Wed, 05-Feb-20',
#   'superseded_by': 1002524,
#   'tag': 'LCLS'},
#  {'elogid': 1002524,
#   'title': 'Peter is returning the east odd sector key we had in the red keysafe',
#   'text': 'Need that keybank complete to make up the 21-29 secure loop so we can go to Ready for Beam and turn on VVS 10 & the injector modulators. The key is not associated with any currently open RSWCFs. ',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1360,
#    'username': 'bripman',
#    'firstname': 'Ben',
#    'lastname': 'Ripman'},
#   'eventTime': 1580963565,
#   'shift': 'Swing Shift, Wed, 05-Feb-20',
#   'supersedes': 1002522,
#   'tag': 'LCLS'},
#  {'elogid': 1002521,
#   'title': 'Contacted Dave Steele; he and R. Kelly will coordinate the initiation of RF processing',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1360,
#    'username': 'bripman',
#    'firstname': 'Ben',
#    'lastname': 'Ripman'},
#   'eventTime': 1580962411,
#   'shift': 'Swing Shift, Wed, 05-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002519,
#   'title': 'Linac East Injector BAS activated',
#   'text': "Paul is heading out to remove the gold locks on VVS10 and the injector modulators. We'll contact R. Kelly and let him know that we the green light to begin processing.",
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1360,
#    'username': 'bripman',
#    'firstname': 'Ben',
#    'lastname': 'Ripman'},
#   'eventTime': 1580961330,
#   'shift': 'Swing Shift, Wed, 05-Feb-20',
#   'highPriority': True,
#   'tag': 'LCLS'},
#  {'elogid': 1002518,
#   'title': 'Hot Sheet',
#   'text': '',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1004,
#    'username': 'schuh',
#    'firstname': 'Peter',
#    'lastname': 'Schuh'},
#   'eventTime': 1580961257,
#   'shift': 'Swing Shift, Wed, 05-Feb-20',
#   'superseded_by': 1002520},
#  {'elogid': 1002520,
#   'title': 'Hot Sheet 033 (SDMP running mode) rescinded and Hot Sheet 034 issued (SDMP running mode update)',
#   'text': 'Clarified use of equipment hatch key as aid in controlling sector 30 access state plus correction of typographical errors',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1004,
#    'username': 'schuh',
#    'firstname': 'Peter',
#    'lastname': 'Schuh'},
#   'eventTime': 1580961257,
#   'shift': 'Swing Shift, Wed, 05-Feb-20',
#   'supersedes': 1002518,
#   'highPriority': True},
#  {'elogid': 1002517,
#   'title': 'S30 equipment hatch key relocated from ACR Red Keysafe to ADSO keysafe.',
#   'text': 'RSWCF 7744 and Linac East key log updated to reflect this.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1425,
#    'username': 'zimmerc',
#    'firstname': 'Christopher',
#    'lastname': 'Zimmer'},
#   'eventTime': 1580954625,
#   'shift': 'Swing Shift, Wed, 05-Feb-20'},
#  {'elogid': 1002514,
#   'title': 'BSY --> PERM',
#   'text': 'Leaving the big concrete door closed; Brad only anticipates bringing a couple people into the zone for a couple of hours in the early morning tomorrow.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1360,
#    'username': 'bripman',
#    'firstname': 'Ben',
#    'lastname': 'Ripman'},
#   'eventTime': 1580951328,
#   'shift': 'Swing Shift, Wed, 05-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002510,
#   'title': 'Zurawel requests that we put the BSY in PERM for PPS work tomorrow morning',
#   'text': "The area doesn't have a search at the moment so I don't see a problem with this.",
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1360,
#    'username': 'bripman',
#    'firstname': 'Ben',
#    'lastname': 'Ripman'},
#   'eventTime': 1580947409,
#   'shift': 'Swing Shift, Wed, 05-Feb-20',
#   'tag': 'LCLS'},
#  {'elogid': 1002513,
#   'title': 'MCC Shift Change: Swing Shift, Wednesday, 05-Feb-2020',
#   'text': 'LCLS: RF processing.\nSPEAR3: User delivery.',
#   'logbook': {'logbookid': 122, 'name': 'MCC'},
#   'author': {'authorid': 1360,
#    'username': 'bripman',
#    'firstname': 'Ben',
#    'lastname': 'Ripman'},
#   'eventTime': 1580947200,
#   'shift': 'Swing Shift, Wed, 05-Feb-20'}]

# %%
r = requests.get('https://github.com/timeline.json')
r.json()
# Out:
# {'message': 'Hello there, wayfaring stranger. If you’re reading this then you probably didn’t see our blog post a couple of years back announcing that this API would go away: http://git.io/17AROg Fear not, you should be able to get what you need from the shiny new Events API instead.',
#  'documentation_url': 'https://developer.github.com/v3/activity/events/#list-public-events'}
